# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("../Data/NewFeatures/disorderPromoting.csv", header=None)
df1Columns = [f"disorderPromoting{i}" for i in range(1, df1.shape[1])]
df1Columns.insert(0, "node")
df1.columns = df1Columns
df1
# Out:
#            node  disorderPromoting1  disorderPromoting2  disorderPromoting3  \
# 0       YDR143C            0.897833            0.049536            0.043344
# 1       YER068W            0.856631            0.057348            0.078853
# 2       YMR207C            0.849287            0.071283            0.068228
# 3       YNR016C            0.860982            0.076923            0.053753
# 4       YIL135C            0.850679            0.085973            0.040724
# ...         ...                 ...                 ...                 ...
# 5565    YJR116W            0.770833            0.072917            0.083333
# 5566    YGR042W            0.846154            0.100000            0.053846
# 5567    YHR002W            0.871951            0.060976            0.054878
# 5568    YBR255W            0.882883            0.042042            0.054054
# 5569  YOR142W-B            0.838951            0.074906            0.069913
#
#       disorderPromoting4  disorderPromoting5  disorderPromoting6  \
# 0               0.000000            0.009288            0.897833
# 1               0.000000            0.007168            0.856631
# 2               0.006110            0.005092            0.849287
# 3               0.002780            0.005561            0.860982
# 4               0.013575            0.009050            0.850679
# ...                  ...                 ...                 ...
# 5565            0.010417            0.062500            0.770833
# 5566            0.000000            0.000000            0.846154
# 5567            0.000000            0.012195            0.871951
# 5568            0.006006            0.015015            0.882883
# 5569            0.006242            0.009988            0.838951
#
#       disorderPromoting7  disorderPromoting8  disorderPromoting9  \
# 0               0.049536            0.043344            0.000000
# 1               0.057348            0.078853            0.000000
# 2               0.071283            0.068228            0.006110
# 3               0.076923            0.053753            0.002780
# 4               0.085973            0.040724            0.013575
# ...                  ...                 ...                 ...
# 5565            0.072917            0.083333            0.010417
# 5566            0.100000            0.053846            0.000000
# 5567            0.060976            0.054878            0.000000
# 5568            0.042042            0.054054            0.006006
# 5569            0.074906            0.069913            0.006242
#
#       disorderPromoting10
# 0                0.009288
# 1                0.007168
# 2                0.005092
# 3                0.005561
# 4                0.009050
# ...                   ...
# 5565             0.062500
# 5566             0.000000
# 5567             0.012195
# 5568             0.015015
# 5569             0.009988
#
# [5570 rows x 11 columns]

# %%
df2 = pd.read_csv("../Data/NewFeatures/hc.csv", header=None)
df2Columns = [f"hc{i}" for i in range(1, df2.shape[1])]
df2Columns.insert(0, "node")
df2.columns = df2Columns
df2
# Out:
#            node       hc1       hc2       hc3       hc4       hc5       hc6  \
# 0       YDR143C  0.363636  0.000000  0.121212  0.060606  0.454545  0.363636
# 1       YER068W  0.293103  0.103448  0.206897  0.034483  0.362069  0.293103
# 2       YMR207C  0.288288  0.063063  0.238739  0.067568  0.342342  0.288288
# 3       YNR016C  0.322870  0.058296  0.215247  0.049327  0.354260  0.322870
# 4       YIL135C  0.323529  0.088235  0.176471  0.088235  0.323529  0.323529
# ...         ...       ...       ...       ...       ...       ...       ...
# 5565    YJR116W  0.416667  0.145833  0.166667  0.062500  0.208333  0.416667
# 5566    YGR042W  0.227273  0.181818  0.227273  0.045455  0.318182  0.227273
# 5567    YHR002W  0.526316  0.052632  0.122807  0.070175  0.228070  0.526316
# 5568    YBR255W  0.448276  0.086207  0.155172  0.068966  0.241379  0.448276
# 5569  YOR142W-B  0.376963  0.078534  0.162304  0.047120  0.335079  0.376963
#
#            hc7       hc8       hc9      hc10
# 0     0.000000  0.121212  0.060606  0.454545
# 1     0.103448  0.206897  0.034483  0.362069
# 2     0.063063  0.238739  0.067568  0.342342
# 3     0.058296  0.215247  0.049327  0.354260
# 4     0.088235  0.176471  0.088235  0.323529
# ...        ...       ...       ...       ...
# 5565  0.145833  0.166667  0.062500  0.208333
# 5566  0.181818  0.227273  0.045455  0.318182
# 5567  0.052632  0.122807  0.070175  0.228070
# 5568  0.086207  0.155172  0.068966  0.241379
# 5569  0.078534  0.162304  0.047120  0.335079
#
# [5570 rows x 11 columns]

# %%
df2ColumnsWONode = df2Columns[1:]
for col in df2ColumnsWONode:
    df2[col].fillna(df2[col].mean(), inplace= True)
    
df2.isna().sum()
# Out:
# node    0
# hc1     0
# hc2     0
# hc3     0
# hc4     0
# hc5     0
# hc6     0
# hc7     0
# hc8     0
# hc9     0
# hc10    0
# dtype: int64

# %%
df3 = pd.read_csv("../Data/NewFeatures/hidrofobik.csv", header=None)
df3Columns = [f"hidrofobik{i}" for i in range(1, df3.shape[1])]
df3Columns.insert(0, "node")
df3.columns = df3Columns
df3
# Out:
#            node  hidrofobik1  hidrofobik2  hidrofobik3  hidrofobik4  \
# 0       YDR143C     0.647887     0.091549     0.133803     0.028169
# 1       YER068W     0.642857     0.119048     0.148810     0.029762
# 2       YMR207C     0.742228     0.084197     0.143782     0.010363
# 3       YNR016C     0.760870     0.077295     0.131643     0.013285
# 4       YIL135C     0.542857     0.095238     0.200000     0.028571
# ...         ...          ...          ...          ...          ...
# 5565    YJR116W     0.880597     0.074627     0.037313     0.000000
# 5566    YGR042W     0.662791     0.104651     0.174419     0.023256
# 5567    YHR002W     0.769784     0.115108     0.079137     0.014388
# 5568    YBR255W     0.675532     0.079787     0.132979     0.026596
# 5569  YOR142W-B     0.650672     0.115163     0.159309     0.023033
#
#       hidrofobik5  hidrofobik6  hidrofobik7  hidrofobik8  hidrofobik9  \
# 0        0.098592     0.647887     0.091549     0.133803     0.028169
# 1        0.059524     0.642857     0.119048     0.148810     0.029762
# 2        0.019430     0.742228     0.084197     0.143782     0.010363
# 3        0.016908     0.760870     0.077295     0.131643     0.013285
# 4        0.133333     0.542857     0.095238     0.200000     0.028571
# ...           ...          ...          ...          ...          ...
# 5565     0.007463     0.880597     0.074627     0.037313     0.000000
# 5566     0.034884     0.662791     0.104651     0.174419     0.023256
# 5567     0.021583     0.769784     0.115108     0.079137     0.014388
# 5568     0.085106     0.675532     0.079787     0.132979     0.026596
# 5569     0.051823     0.650672     0.115163     0.159309     0.023033
#
#       hidrofobik10
# 0         0.098592
# 1         0.059524
# 2         0.019430
# 3         0.016908
# 4         0.133333
# ...            ...
# 5565      0.007463
# 5566      0.034884
# 5567      0.021583
# 5568      0.085106
# 5569      0.051823
#
# [5570 rows x 11 columns]

# %%
df4 = pd.read_csv("../Data/NewFeatures/nonZero.csv", header=None)
df4Columns = [f"nonZero{i}" for i in range(1, df4.shape[1])]
df4Columns.insert(0, "node")
df4.columns = df4Columns
df4
# Out:
#            node  nonZero1  nonZero2  nonZero3  nonZero4  nonZero5  nonZero6  \
# 0       YDR143C  0.983740  0.012195  0.004065       0.0       0.0  0.983740
# 1       YER068W  0.993548  0.006452  0.000000       0.0       0.0  0.993548
# 2       YMR207C  0.983871  0.012903  0.003226       0.0       0.0  0.983871
# 3       YNR016C  0.979087  0.015843  0.005070       0.0       0.0  0.979087
# 4       YIL135C  0.991329  0.008671  0.000000       0.0       0.0  0.991329
# ...         ...       ...       ...       ...       ...       ...       ...
# 5565    YJR116W  0.940476  0.035714  0.023810       0.0       0.0  0.940476
# 5566    YGR042W  0.976077  0.019139  0.004785       0.0       0.0  0.976077
# 5567    YHR002W  0.972222  0.027778  0.000000       0.0       0.0  0.972222
# 5568    YBR255W  0.989170  0.005415  0.005415       0.0       0.0  0.989170
# 5569  YOR142W-B  0.989833  0.009441  0.000726       0.0       0.0  0.989833
#
#       nonZero7  nonZero8  nonZero9  nonZero10
# 0     0.012195  0.004065       0.0        0.0
# 1     0.006452  0.000000       0.0        0.0
# 2     0.012903  0.003226       0.0        0.0
# 3     0.015843  0.005070       0.0        0.0
# 4     0.008671  0.000000       0.0        0.0
# ...        ...       ...       ...        ...
# 5565  0.035714  0.023810       0.0        0.0
# 5566  0.019139  0.004785       0.0        0.0
# 5567  0.027778  0.000000       0.0        0.0
# 5568  0.005415  0.005415       0.0        0.0
# 5569  0.009441  0.000726       0.0        0.0
#
# [5570 rows x 11 columns]

# %%
df5 = pd.read_csv("../Data/NewFeatures/polar.csv", header=None)
df5Columns = [f"polar{i}" for i in range(1, df5.shape[1])]
df5Columns.insert(0, "node")
df5.columns = df5Columns
df5
# Out:
#            node    polar1    polar2    polar3    polar4    polar5    polar6  \
# 0       YDR143C  0.936340  0.034483  0.029178  0.000000  0.000000  0.819742
# 1       YER068W  0.936232  0.026087  0.028986  0.005797  0.002899  0.814050
# 2       YMR207C  0.895401  0.063120  0.034265  0.002705  0.004509  0.861933
# 3       YNR016C  0.885537  0.060337  0.045253  0.005324  0.003549  0.886980
# 4       YIL135C  0.954225  0.031690  0.014085  0.000000  0.000000  0.736842
# ...         ...       ...       ...       ...       ...       ...       ...
# 5565    YJR116W  0.760684  0.128205  0.111111  0.000000  0.000000  0.944444
# 5566    YGR042W  0.944785  0.036810  0.018405  0.000000  0.000000  0.805556
# 5567    YHR002W  0.872832  0.075145  0.046243  0.005780  0.000000  0.891304
# 5568    YBR255W  0.946759  0.027778  0.023148  0.000000  0.002315  0.763359
# 5569  YOR142W-B  0.927536  0.041546  0.029952  0.000966  0.000000  0.800000
#
#         polar7    polar8    polar9   polar10
# 0     0.042918  0.090129  0.012876  0.034335
# 1     0.070248  0.078512  0.012397  0.024793
# 2     0.071006  0.063116  0.001972  0.001972
# 3     0.053345  0.053345  0.005425  0.000904
# 4     0.098684  0.098684  0.006579  0.059211
# ...        ...       ...       ...       ...
# 5565  0.024691  0.024691  0.000000  0.006173
# 5566  0.074074  0.101852  0.000000  0.018519
# 5567  0.048913  0.043478  0.005435  0.010870
# 5568  0.083969  0.099237  0.022901  0.030534
# 5569  0.079167  0.093056  0.012500  0.015278
#
# [5570 rows x 11 columns]

# %%
df6 = pd.read_csv("../Data/NewFeatures/positive.csv", header=None)
df6Columns = [f"positive{i}" for i in range(1, df6.shape[1])]
df6Columns.insert(0, "node")
df6.columns = df6Columns
df6
# Out:
#            node  positive1  positive2  positive3  positive4  positive5  \
# 0       YDR143C   0.912676   0.039437   0.033803   0.008451   0.005634
# 1       YER068W   0.910448   0.050746   0.032836   0.000000   0.005970
# 2       YMR207C   0.923957   0.044154   0.030253   0.001635   0.000000
# 3       YNR016C   0.940377   0.030943   0.027925   0.000755   0.000000
# 4       YIL135C   0.914634   0.036585   0.040650   0.004065   0.004065
# ...         ...        ...        ...        ...        ...        ...
# 5565    YJR116W   0.974093   0.015544   0.010363   0.000000   0.000000
# 5566    YGR042W   0.915493   0.028169   0.056338   0.000000   0.000000
# 5567    YHR002W   0.942222   0.031111   0.026667   0.000000   0.000000
# 5568    YBR255W   0.905759   0.044503   0.044503   0.002618   0.002618
# 5569  YOR142W-B   0.921844   0.047094   0.029058   0.000000   0.002004
#
#       positive6  positive7  positive8  positive9  positive10
# 0      0.912676   0.039437   0.033803   0.008451    0.005634
# 1      0.910448   0.050746   0.032836   0.000000    0.005970
# 2      0.923957   0.044154   0.030253   0.001635    0.000000
# 3      0.940377   0.030943   0.027925   0.000755    0.000000
# 4      0.914634   0.036585   0.040650   0.004065    0.004065
# ...         ...        ...        ...        ...         ...
# 5565   0.974093   0.015544   0.010363   0.000000    0.000000
# 5566   0.915493   0.028169   0.056338   0.000000    0.000000
# 5567   0.942222   0.031111   0.026667   0.000000    0.000000
# 5568   0.905759   0.044503   0.044503   0.002618    0.002618
# 5569   0.921844   0.047094   0.029058   0.000000    0.002004
#
# [5570 rows x 11 columns]

# %%
merged_df = pd.merge(df1, df2, on='node')
merged_df = pd.merge(merged_df, df3, on='node')
merged_df = pd.merge(merged_df, df4, on='node')
merged_df = pd.merge(merged_df, df5, on='node')
merged_df = pd.merge(merged_df, df6, on='node')
merged_df
# Out:
#            node  disorderPromoting1  disorderPromoting2  disorderPromoting3  \
# 0       YDR143C            0.897833            0.049536            0.043344
# 1       YER068W            0.856631            0.057348            0.078853
# 2       YMR207C            0.849287            0.071283            0.068228
# 3       YNR016C            0.860982            0.076923            0.053753
# 4       YIL135C            0.850679            0.085973            0.040724
# ...         ...                 ...                 ...                 ...
# 5565    YJR116W            0.770833            0.072917            0.083333
# 5566    YGR042W            0.846154            0.100000            0.053846
# 5567    YHR002W            0.871951            0.060976            0.054878
# 5568    YBR255W            0.882883            0.042042            0.054054
# 5569  YOR142W-B            0.838951            0.074906            0.069913
#
#       disorderPromoting4  disorderPromoting5  disorderPromoting6  \
# 0               0.000000            0.009288            0.897833
# 1               0.000000            0.007168            0.856631
# 2               0.006110            0.005092            0.849287
# 3               0.002780            0.005561            0.860982
# 4               0.013575            0.009050            0.850679
# ...                  ...                 ...                 ...
# 5565            0.010417            0.062500            0.770833
# 5566            0.000000            0.000000            0.846154
# 5567            0.000000            0.012195            0.871951
# 5568            0.006006            0.015015            0.882883
# 5569            0.006242            0.009988            0.838951
#
#       disorderPromoting7  disorderPromoting8  disorderPromoting9  ...  \
# 0               0.049536            0.043344            0.000000  ...
# 1               0.057348            0.078853            0.000000  ...
# 2               0.071283            0.068228            0.006110  ...
# 3               0.076923            0.053753            0.002780  ...
# 4               0.085973            0.040724            0.013575  ...
# ...                  ...                 ...                 ...  ...
# 5565            0.072917            0.083333            0.010417  ...
# 5566            0.100000            0.053846            0.000000  ...
# 5567            0.060976            0.054878            0.000000  ...
# 5568            0.042042            0.054054            0.006006  ...
# 5569            0.074906            0.069913            0.006242  ...
#
#       positive1  positive2  positive3  positive4  positive5  positive6  \
# 0      0.912676   0.039437   0.033803   0.008451   0.005634   0.912676
# 1      0.910448   0.050746   0.032836   0.000000   0.005970   0.910448
# 2      0.923957   0.044154   0.030253   0.001635   0.000000   0.923957
# 3      0.940377   0.030943   0.027925   0.000755   0.000000   0.940377
# 4      0.914634   0.036585   0.040650   0.004065   0.004065   0.914634
# ...         ...        ...        ...        ...        ...        ...
# 5565   0.974093   0.015544   0.010363   0.000000   0.000000   0.974093
# 5566   0.915493   0.028169   0.056338   0.000000   0.000000   0.915493
# 5567   0.942222   0.031111   0.026667   0.000000   0.000000   0.942222
# 5568   0.905759   0.044503   0.044503   0.002618   0.002618   0.905759
# 5569   0.921844   0.047094   0.029058   0.000000   0.002004   0.921844
#
#       positive7  positive8  positive9  positive10
# 0      0.039437   0.033803   0.008451    0.005634
# 1      0.050746   0.032836   0.000000    0.005970
# 2      0.044154   0.030253   0.001635    0.000000
# 3      0.030943   0.027925   0.000755    0.000000
# 4      0.036585   0.040650   0.004065    0.004065
# ...         ...        ...        ...         ...
# 5565   0.015544   0.010363   0.000000    0.000000
# 5566   0.028169   0.056338   0.000000    0.000000
# 5567   0.031111   0.026667   0.000000    0.000000
# 5568   0.044503   0.044503   0.002618    0.002618
# 5569   0.047094   0.029058   0.000000    0.002004
#
# [5570 rows x 61 columns]

# %%
with open ("../Data/yeast/disprotYeast194.txt", "r") as inputFile:
    disProt = [line.strip() for line in inputFile]

# %%
def assignLabel(node, IDPs):
    if node in IDPs:
        return 1
    return 0

# %%
labels = []
for node in merged_df["node"]:
    labels.append(assignLabel(node, disProt))
    
merged_df.insert(1, "label", labels)
merged_df
# Out:
#            node  label  disorderPromoting1  disorderPromoting2  \
# 0       YDR143C      1            0.897833            0.049536
# 1       YER068W      0            0.856631            0.057348
# 2       YMR207C      0            0.849287            0.071283
# 3       YNR016C      1            0.860982            0.076923
# 4       YIL135C      0            0.850679            0.085973
# ...         ...    ...                 ...                 ...
# 5565    YJR116W      0            0.770833            0.072917
# 5566    YGR042W      0            0.846154            0.100000
# 5567    YHR002W      0            0.871951            0.060976
# 5568    YBR255W      0            0.882883            0.042042
# 5569  YOR142W-B      0            0.838951            0.074906
#
#       disorderPromoting3  disorderPromoting4  disorderPromoting5  \
# 0               0.043344            0.000000            0.009288
# 1               0.078853            0.000000            0.007168
# 2               0.068228            0.006110            0.005092
# 3               0.053753            0.002780            0.005561
# 4               0.040724            0.013575            0.009050
# ...                  ...                 ...                 ...
# 5565            0.083333            0.010417            0.062500
# 5566            0.053846            0.000000            0.000000
# 5567            0.054878            0.000000            0.012195
# 5568            0.054054            0.006006            0.015015
# 5569            0.069913            0.006242            0.009988
#
#       disorderPromoting6  disorderPromoting7  disorderPromoting8  ...  \
# 0               0.897833            0.049536            0.043344  ...
# 1               0.856631            0.057348            0.078853  ...
# 2               0.849287            0.071283            0.068228  ...
# 3               0.860982            0.076923            0.053753  ...
# 4               0.850679            0.085973            0.040724  ...
# ...                  ...                 ...                 ...  ...
# 5565            0.770833            0.072917            0.083333  ...
# 5566            0.846154            0.100000            0.053846  ...
# 5567            0.871951            0.060976            0.054878  ...
# 5568            0.882883            0.042042            0.054054  ...
# 5569            0.838951            0.074906            0.069913  ...
#
#       positive1  positive2  positive3  positive4  positive5  positive6  \
# 0      0.912676   0.039437   0.033803   0.008451   0.005634   0.912676
# 1      0.910448   0.050746   0.032836   0.000000   0.005970   0.910448
# 2      0.923957   0.044154   0.030253   0.001635   0.000000   0.923957
# 3      0.940377   0.030943   0.027925   0.000755   0.000000   0.940377
# 4      0.914634   0.036585   0.040650   0.004065   0.004065   0.914634
# ...         ...        ...        ...        ...        ...        ...
# 5565   0.974093   0.015544   0.010363   0.000000   0.000000   0.974093
# 5566   0.915493   0.028169   0.056338   0.000000   0.000000   0.915493
# 5567   0.942222   0.031111   0.026667   0.000000   0.000000   0.942222
# 5568   0.905759   0.044503   0.044503   0.002618   0.002618   0.905759
# 5569   0.921844   0.047094   0.029058   0.000000   0.002004   0.921844
#
#       positive7  positive8  positive9  positive10
# 0      0.039437   0.033803   0.008451    0.005634
# 1      0.050746   0.032836   0.000000    0.005970
# 2      0.044154   0.030253   0.001635    0.000000
# 3      0.030943   0.027925   0.000755    0.000000
# 4      0.036585   0.040650   0.004065    0.004065
# ...         ...        ...        ...         ...
# 5565   0.015544   0.010363   0.000000    0.000000
# 5566   0.028169   0.056338   0.000000    0.000000
# 5567   0.031111   0.026667   0.000000    0.000000
# 5568   0.044503   0.044503   0.002618    0.002618
# 5569   0.047094   0.029058   0.000000    0.002004
#
# [5570 rows x 62 columns]

# %%
embeding = pd.read_csv("../Data/NewEmbedings/embed_p2_q1_notW.csv", header=None)
embeding
# Out:
#             0         1         2         3         4         5         6    \
# 0       YDR143C  0.489355 -0.133820 -0.104743  0.355404  0.248795  0.082276
# 1       YER068W -0.181563 -0.106796 -0.251416  0.133842  0.290794  0.046451
# 2       YMR207C -0.127260 -0.376882  0.007594  0.197129  0.034433 -0.177042
# 3       YNR016C  0.120612 -0.389956  0.042595  0.266715  0.239850 -0.317591
# 4       YIL135C -0.137359 -0.522142 -0.188407  0.095474 -0.002379 -0.012450
# ...         ...       ...       ...       ...       ...       ...       ...
# 5635    YGR042W  0.037341 -0.163460  0.061125 -0.004426  0.008056 -0.047935
# 5636    YHR002W  0.193310 -0.347681 -0.157674  0.083066  0.028100 -0.197454
# 5637    YBR255W  0.107947 -0.224621 -0.229771  0.146322  0.159148 -0.235389
# 5638   TS(AGA)A  0.073116 -0.243561 -0.175079  0.282072  0.202851 -0.227292
# 5639  YOR142W-B  0.096220 -0.195939 -0.023665  0.133309  0.262208 -0.194695
#
#            7         8         9    ...       119       120       121  \
# 0    -0.393408  0.462355  0.424525  ... -0.342792 -0.037661 -0.010074
# 1    -0.372687  0.223309  0.281151  ... -0.177044 -0.517876  0.014820
# 2    -0.017106  0.111959  0.035569  ...  0.078918 -0.064612 -0.116809
# 3     0.062092 -0.064162 -0.082341  ... -0.043434 -0.160771 -0.255714
# 4     0.000927  0.152697  0.139736  ...  0.375822 -0.203216 -0.283696
# ...        ...       ...       ...  ...       ...       ...       ...
# 5635 -0.080931  0.206594  0.209294  ...  0.017505 -0.069286 -0.113899
# 5636  0.029697  0.367927  0.151034  ...  0.155770  0.175897 -0.036742
# 5637 -0.207438  0.191829  0.067555  ...  0.240121 -0.044798 -0.366436
# 5638 -0.515775  0.076924  0.166144  ...  0.132517  0.085604 -0.174474
# 5639 -0.120185  0.219112  0.394333  ...  0.098908  0.016317 -0.123577
#
#            122       123       124       125       126       127       128
# 0    -0.011061 -0.127494 -0.124377  0.156678  0.227350 -0.379476 -0.437927
# 1     0.090105 -0.351522 -0.533959 -0.272060  0.015745 -0.596109 -0.217360
# 2    -0.012231 -0.282247 -0.113117  0.156484 -0.064082 -0.096498 -0.031781
# 3     0.011584 -0.132607 -0.388262 -0.016025  0.149189  0.060363  0.231024
# 4     0.048688 -0.136596  0.231517  0.119675  0.202780 -0.023230 -0.067822
# ...        ...       ...       ...       ...       ...       ...       ...
# 5635 -0.074234 -0.098797  0.162219 -0.005060  0.061725 -0.016395 -0.073249
# 5636  0.275517 -0.038799 -0.064079 -0.195498 -0.030828  0.251061 -0.044431
# 5637  0.228716 -0.174457  0.023809 -0.071392  0.065229 -0.221041  0.026377
# 5638  0.401801 -0.050438  0.244951  0.065264  0.389543 -0.132763 -0.124885
# 5639  0.238211 -0.276999  0.096169 -0.099909  0.018608 -0.022034  0.067858
#
# [5640 rows x 129 columns]

# %%
columnsEmbeding = [f"embeding{i}" for i in range(1, embeding.shape[1])]
columnsEmbeding.insert(0, "node")
embeding.columns = columnsEmbeding
embeding
# Out:
#            node  embeding1  embeding2  embeding3  embeding4  embeding5  \
# 0       YDR143C   0.489355  -0.133820  -0.104743   0.355404   0.248795
# 1       YER068W  -0.181563  -0.106796  -0.251416   0.133842   0.290794
# 2       YMR207C  -0.127260  -0.376882   0.007594   0.197129   0.034433
# 3       YNR016C   0.120612  -0.389956   0.042595   0.266715   0.239850
# 4       YIL135C  -0.137359  -0.522142  -0.188407   0.095474  -0.002379
# ...         ...        ...        ...        ...        ...        ...
# 5635    YGR042W   0.037341  -0.163460   0.061125  -0.004426   0.008056
# 5636    YHR002W   0.193310  -0.347681  -0.157674   0.083066   0.028100
# 5637    YBR255W   0.107947  -0.224621  -0.229771   0.146322   0.159148
# 5638   TS(AGA)A   0.073116  -0.243561  -0.175079   0.282072   0.202851
# 5639  YOR142W-B   0.096220  -0.195939  -0.023665   0.133309   0.262208
#
#       embeding6  embeding7  embeding8  embeding9  ...  embeding119  \
# 0      0.082276  -0.393408   0.462355   0.424525  ...    -0.342792
# 1      0.046451  -0.372687   0.223309   0.281151  ...    -0.177044
# 2     -0.177042  -0.017106   0.111959   0.035569  ...     0.078918
# 3     -0.317591   0.062092  -0.064162  -0.082341  ...    -0.043434
# 4     -0.012450   0.000927   0.152697   0.139736  ...     0.375822
# ...         ...        ...        ...        ...  ...          ...
# 5635  -0.047935  -0.080931   0.206594   0.209294  ...     0.017505
# 5636  -0.197454   0.029697   0.367927   0.151034  ...     0.155770
# 5637  -0.235389  -0.207438   0.191829   0.067555  ...     0.240121
# 5638  -0.227292  -0.515775   0.076924   0.166144  ...     0.132517
# 5639  -0.194695  -0.120185   0.219112   0.394333  ...     0.098908
#
#       embeding120  embeding121  embeding122  embeding123  embeding124  \
# 0       -0.037661    -0.010074    -0.011061    -0.127494    -0.124377
# 1       -0.517876     0.014820     0.090105    -0.351522    -0.533959
# 2       -0.064612    -0.116809    -0.012231    -0.282247    -0.113117
# 3       -0.160771    -0.255714     0.011584    -0.132607    -0.388262
# 4       -0.203216    -0.283696     0.048688    -0.136596     0.231517
# ...           ...          ...          ...          ...          ...
# 5635    -0.069286    -0.113899    -0.074234    -0.098797     0.162219
# 5636     0.175897    -0.036742     0.275517    -0.038799    -0.064079
# 5637    -0.044798    -0.366436     0.228716    -0.174457     0.023809
# 5638     0.085604    -0.174474     0.401801    -0.050438     0.244951
# 5639     0.016317    -0.123577     0.238211    -0.276999     0.096169
#
#       embeding125  embeding126  embeding127  embeding128
# 0        0.156678     0.227350    -0.379476    -0.437927
# 1       -0.272060     0.015745    -0.596109    -0.217360
# 2        0.156484    -0.064082    -0.096498    -0.031781
# 3       -0.016025     0.149189     0.060363     0.231024
# 4        0.119675     0.202780    -0.023230    -0.067822
# ...           ...          ...          ...          ...
# 5635    -0.005060     0.061725    -0.016395    -0.073249
# 5636    -0.195498    -0.030828     0.251061    -0.044431
# 5637    -0.071392     0.065229    -0.221041     0.026377
# 5638     0.065264     0.389543    -0.132763    -0.124885
# 5639    -0.099909     0.018608    -0.022034     0.067858
#
# [5640 rows x 129 columns]

# %%
merged_df = pd.merge(merged_df, embeding, on='node')
merged_df
# Out:
#            node  label  disorderPromoting1  disorderPromoting2  \
# 0       YDR143C      1            0.897833            0.049536
# 1       YER068W      0            0.856631            0.057348
# 2       YMR207C      0            0.849287            0.071283
# 3       YNR016C      1            0.860982            0.076923
# 4       YIL135C      0            0.850679            0.085973
# ...         ...    ...                 ...                 ...
# 5565    YJR116W      0            0.770833            0.072917
# 5566    YGR042W      0            0.846154            0.100000
# 5567    YHR002W      0            0.871951            0.060976
# 5568    YBR255W      0            0.882883            0.042042
# 5569  YOR142W-B      0            0.838951            0.074906
#
#       disorderPromoting3  disorderPromoting4  disorderPromoting5  \
# 0               0.043344            0.000000            0.009288
# 1               0.078853            0.000000            0.007168
# 2               0.068228            0.006110            0.005092
# 3               0.053753            0.002780            0.005561
# 4               0.040724            0.013575            0.009050
# ...                  ...                 ...                 ...
# 5565            0.083333            0.010417            0.062500
# 5566            0.053846            0.000000            0.000000
# 5567            0.054878            0.000000            0.012195
# 5568            0.054054            0.006006            0.015015
# 5569            0.069913            0.006242            0.009988
#
#       disorderPromoting6  disorderPromoting7  disorderPromoting8  ...  \
# 0               0.897833            0.049536            0.043344  ...
# 1               0.856631            0.057348            0.078853  ...
# 2               0.849287            0.071283            0.068228  ...
# 3               0.860982            0.076923            0.053753  ...
# 4               0.850679            0.085973            0.040724  ...
# ...                  ...                 ...                 ...  ...
# 5565            0.770833            0.072917            0.083333  ...
# 5566            0.846154            0.100000            0.053846  ...
# 5567            0.871951            0.060976            0.054878  ...
# 5568            0.882883            0.042042            0.054054  ...
# 5569            0.838951            0.074906            0.069913  ...
#
#       embeding119  embeding120  embeding121  embeding122  embeding123  \
# 0       -0.342792    -0.037661    -0.010074    -0.011061    -0.127494
# 1       -0.177044    -0.517876     0.014820     0.090105    -0.351522
# 2        0.078918    -0.064612    -0.116809    -0.012231    -0.282247
# 3       -0.043434    -0.160771    -0.255714     0.011584    -0.132607
# 4        0.375822    -0.203216    -0.283696     0.048688    -0.136596
# ...           ...          ...          ...          ...          ...
# 5565     0.124380     0.043094    -0.157688    -0.137584    -0.139322
# 5566     0.017505    -0.069286    -0.113899    -0.074234    -0.098797
# 5567     0.155770     0.175897    -0.036742     0.275517    -0.038799
# 5568     0.240121    -0.044798    -0.366436     0.228716    -0.174457
# 5569     0.098908     0.016317    -0.123577     0.238211    -0.276999
#
#       embeding124  embeding125  embeding126  embeding127  embeding128
# 0       -0.124377     0.156678     0.227350    -0.379476    -0.437927
# 1       -0.533959    -0.272060     0.015745    -0.596109    -0.217360
# 2       -0.113117     0.156484    -0.064082    -0.096498    -0.031781
# 3       -0.388262    -0.016025     0.149189     0.060363     0.231024
# 4        0.231517     0.119675     0.202780    -0.023230    -0.067822
# ...           ...          ...          ...          ...          ...
# 5565     0.119691    -0.026695     0.044442     0.046044    -0.134722
# 5566     0.162219    -0.005060     0.061725    -0.016395    -0.073249
# 5567    -0.064079    -0.195498    -0.030828     0.251061    -0.044431
# 5568     0.023809    -0.071392     0.065229    -0.221041     0.026377
# 5569     0.096169    -0.099909     0.018608    -0.022034     0.067858
#
# [5570 rows x 190 columns]

# %%
for col in merged_df.columns:
    print(col)
# Out:
# node
# label
# disorderPromoting1
# disorderPromoting2
# disorderPromoting3
# disorderPromoting4
# disorderPromoting5
# disorderPromoting6
# disorderPromoting7
# disorderPromoting8
# disorderPromoting9
# disorderPromoting10
# hc1
# hc2
# hc3
# hc4
# hc5
# hc6
# hc7
# hc8
# hc9
# hc10
# hidrofobik1
# hidrofobik2
# hidrofobik3
# hidrofobik4
# hidrofobik5
# hidrofobik6
# hidrofobik7
# hidrofobik8
# hidrofobik9
# hidrofobik10
# nonZero1
# nonZero2
# nonZero3
# nonZero4
# nonZero5
# nonZero6
# nonZero7
# nonZero8
# nonZero9
# nonZero10
# polar1
# polar2
# polar3
# polar4
# polar5
# polar6
# polar7
# polar8
# polar9
# polar10
# positive1
# positive2
# positive3
# positive4
# positive5
# positive6
# positive7
# positive8
# positive9
# positive10
# embeding1
# embeding2
# embeding3
# embeding4
# embeding5
# embeding6
# embeding7
# embeding8
# embeding9
# embeding10
# embeding11
# embeding12
# embeding13
# embeding14
# embeding15
# embeding16
# embeding17
# embeding18
# embeding19
# embeding20
# embeding21
# embeding22
# embeding23
# embeding24
# embeding25
# embeding26
# embeding27
# embeding28
# embeding29
# embeding30
# embeding31
# embeding32
# embeding33
# embeding34
# embeding35
# embeding36
# embeding37
# embeding38
# embeding39
# embeding40
# embeding41
# embeding42
# embeding43
# embeding44
# embeding45
# embeding46
# embeding47
# embeding48
# embeding49
# embeding50
# embeding51
# embeding52
# embeding53
# embeding54
# embeding55
# embeding56
# embeding57
# embeding58
# embeding59
# embeding60
# embeding61
# embeding62
# embeding63
# embeding64
# embeding65
# embeding66
# embeding67
# embeding68
# embeding69
# embeding70
# embeding71
# embeding72
# embeding73
# embeding74
# embeding75
# embeding76
# embeding77
# embeding78
# embeding79
# embeding80
# embeding81
# embeding82
# embeding83
# embeding84
# embeding85
# embeding86
# embeding87
# embeding88
# embeding89
# embeding90
# embeding91
# embeding92
# embeding93
# embeding94
# embeding95
# embeding96
# embeding97
# embeding98
# embeding99
# embeding100
# embeding101
# embeding102
# embeding103
# embeding104
# embeding105
# embeding106
# embeding107
# embeding108
# embeding109
# embeding110
# embeding111
# embeding112
# embeding113
# embeding114
# embeding115
# embeding116
# embeding117
# embeding118
# embeding119
# embeding120
# embeding121
# embeding122
# embeding123
# embeding124
# embeding125
# embeding126
# embeding127
# embeding128

# %%
x = merged_df[merged_df.columns[2::]]
x
# Out:
#       disorderPromoting1  disorderPromoting2  disorderPromoting3  \
# 0               0.897833            0.049536            0.043344
# 1               0.856631            0.057348            0.078853
# 2               0.849287            0.071283            0.068228
# 3               0.860982            0.076923            0.053753
# 4               0.850679            0.085973            0.040724
# ...                  ...                 ...                 ...
# 5565            0.770833            0.072917            0.083333
# 5566            0.846154            0.100000            0.053846
# 5567            0.871951            0.060976            0.054878
# 5568            0.882883            0.042042            0.054054
# 5569            0.838951            0.074906            0.069913
#
#       disorderPromoting4  disorderPromoting5  disorderPromoting6  \
# 0               0.000000            0.009288            0.897833
# 1               0.000000            0.007168            0.856631
# 2               0.006110            0.005092            0.849287
# 3               0.002780            0.005561            0.860982
# 4               0.013575            0.009050            0.850679
# ...                  ...                 ...                 ...
# 5565            0.010417            0.062500            0.770833
# 5566            0.000000            0.000000            0.846154
# 5567            0.000000            0.012195            0.871951
# 5568            0.006006            0.015015            0.882883
# 5569            0.006242            0.009988            0.838951
#
#       disorderPromoting7  disorderPromoting8  disorderPromoting9  \
# 0               0.049536            0.043344            0.000000
# 1               0.057348            0.078853            0.000000
# 2               0.071283            0.068228            0.006110
# 3               0.076923            0.053753            0.002780
# 4               0.085973            0.040724            0.013575
# ...                  ...                 ...                 ...
# 5565            0.072917            0.083333            0.010417
# 5566            0.100000            0.053846            0.000000
# 5567            0.060976            0.054878            0.000000
# 5568            0.042042            0.054054            0.006006
# 5569            0.074906            0.069913            0.006242
#
#       disorderPromoting10  ...  embeding119  embeding120  embeding121  \
# 0                0.009288  ...    -0.342792    -0.037661    -0.010074
# 1                0.007168  ...    -0.177044    -0.517876     0.014820
# 2                0.005092  ...     0.078918    -0.064612    -0.116809
# 3                0.005561  ...    -0.043434    -0.160771    -0.255714
# 4                0.009050  ...     0.375822    -0.203216    -0.283696
# ...                   ...  ...          ...          ...          ...
# 5565             0.062500  ...     0.124380     0.043094    -0.157688
# 5566             0.000000  ...     0.017505    -0.069286    -0.113899
# 5567             0.012195  ...     0.155770     0.175897    -0.036742
# 5568             0.015015  ...     0.240121    -0.044798    -0.366436
# 5569             0.009988  ...     0.098908     0.016317    -0.123577
#
#       embeding122  embeding123  embeding124  embeding125  embeding126  \
# 0       -0.011061    -0.127494    -0.124377     0.156678     0.227350
# 1        0.090105    -0.351522    -0.533959    -0.272060     0.015745
# 2       -0.012231    -0.282247    -0.113117     0.156484    -0.064082
# 3        0.011584    -0.132607    -0.388262    -0.016025     0.149189
# 4        0.048688    -0.136596     0.231517     0.119675     0.202780
# ...           ...          ...          ...          ...          ...
# 5565    -0.137584    -0.139322     0.119691    -0.026695     0.044442
# 5566    -0.074234    -0.098797     0.162219    -0.005060     0.061725
# 5567     0.275517    -0.038799    -0.064079    -0.195498    -0.030828
# 5568     0.228716    -0.174457     0.023809    -0.071392     0.065229
# 5569     0.238211    -0.276999     0.096169    -0.099909     0.018608
#
#       embeding127  embeding128
# 0       -0.379476    -0.437927
# 1       -0.596109    -0.217360
# 2       -0.096498    -0.031781
# 3        0.060363     0.231024
# 4       -0.023230    -0.067822
# ...           ...          ...
# 5565     0.046044    -0.134722
# 5566    -0.016395    -0.073249
# 5567     0.251061    -0.044431
# 5568    -0.221041     0.026377
# 5569    -0.022034     0.067858
#
# [5570 rows x 188 columns]

# %%
df = merged_df

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
scaler = MinMaxScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns = x.columns)
x
# Out:
#       disorderPromoting1  disorderPromoting2  disorderPromoting3  \
# 0               0.810261            0.128793            0.158927
# 1               0.733743            0.149104            0.289128
# 2               0.720105            0.185336            0.250170
# 3               0.741824            0.200000            0.197096
# 4               0.722689            0.223529            0.149321
# ...                  ...                 ...                 ...
# 5565            0.574405            0.189583            0.305556
# 5566            0.714286            0.260000            0.197436
# 5567            0.762195            0.158537            0.201220
# 5568            0.782497            0.109309            0.198198
# 5569            0.700910            0.194757            0.256346
#
#       disorderPromoting4  disorderPromoting5  disorderPromoting6  \
# 0               0.000000            0.077399            0.810261
# 1               0.000000            0.059737            0.733743
# 2               0.054990            0.042430            0.720105
# 3               0.025023            0.046339            0.741824
# 4               0.122172            0.075415            0.722689
# ...                  ...                 ...                 ...
# 5565            0.093750            0.520833            0.574405
# 5566            0.000000            0.000000            0.714286
# 5567            0.000000            0.101626            0.762195
# 5568            0.054054            0.125125            0.782497
# 5569            0.056180            0.083229            0.700910
#
#       disorderPromoting7  disorderPromoting8  disorderPromoting9  \
# 0               0.128793            0.158927            0.000000
# 1               0.149104            0.289128            0.000000
# 2               0.185336            0.250170            0.054990
# 3               0.200000            0.197096            0.025023
# 4               0.223529            0.149321            0.122172
# ...                  ...                 ...                 ...
# 5565            0.189583            0.305556            0.093750
# 5566            0.260000            0.197436            0.000000
# 5567            0.158537            0.201220            0.000000
# 5568            0.109309            0.198198            0.054054
# 5569            0.194757            0.256346            0.056180
#
#       disorderPromoting10  ...  embeding119  embeding120  embeding121  \
# 0                0.077399  ...     0.222645     0.516914     0.601531
# 1                0.059737  ...     0.341490     0.189923     0.618611
# 2                0.042430  ...     0.525021     0.498563     0.528297
# 3                0.046339  ...     0.437292     0.433086     0.432990
# 4                0.075415  ...     0.737908     0.404184     0.413791
# ...                   ...  ...          ...          ...          ...
# 5565             0.520833  ...     0.557619     0.571903     0.500248
# 5566             0.000000  ...     0.480986     0.495380     0.530294
# 5567             0.101626  ...     0.580126     0.662332     0.583233
# 5568             0.125125  ...     0.640608     0.512055     0.357020
# 5569             0.083229  ...     0.539355     0.553669     0.523653
#
#       embeding122  embeding123  embeding124  embeding125  embeding126  \
# 0        0.523205     0.574471     0.337411     0.568655     0.629088
# 1        0.595809     0.418335     0.095448     0.318456     0.499118
# 2        0.522365     0.466616     0.344064     0.568542     0.450088
# 3        0.539457     0.570907     0.181519     0.467870     0.581081
# 4        0.566085     0.568127     0.547659     0.547061     0.613997
# ...           ...          ...          ...          ...          ...
# 5565     0.432404     0.566227     0.481597     0.461644     0.516745
# 5566     0.477868     0.594471     0.506720     0.474269     0.527360
# 5567     0.728873     0.636286     0.373033     0.363136     0.470513
# 5568     0.695285     0.541740     0.424953     0.435560     0.529512
# 5569     0.702100     0.470274     0.467701     0.418919     0.500877
#
#       embeding127  embeding128
# 0        0.306047     0.223213
# 1        0.162391     0.371462
# 2        0.493698     0.496195
# 3        0.597717     0.672834
# 4        0.542284     0.471971
# ...           ...          ...
# 5565     0.588221     0.427006
# 5566     0.546816     0.468323
# 5567     0.724174     0.487693
# 5568     0.411109     0.535285
# 5569     0.543077     0.563165
#
# [5570 rows x 188 columns]

# %%
def IDPsInCluster(cluster):
    return (cluster["label"] == 1).sum()

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

SSERandom = []
SSEKmeans = []
silhouette_scoresRandom = []
silhouette_scoresKmeans = []

numOfclusters = range(100, 801, 50)
for i in numOfclusters:
    for init in ['k-means++', 'random']:
        print(f"{i} clusters, init : {init}")

        kmeans=KMeans(n_clusters=i, init=init, n_init = 10)
        kmeans.fit(x)

        if init == 'random':
            SSERandom.append(kmeans.inertia_)
            silhouette_scoresRandom.append(silhouette_score(x, kmeans.labels_))
        else:
            SSEKmeans.append(kmeans.inertia_)
            silhouette_scoresKmeans.append(silhouette_score(x, kmeans.labels_))

        for j in range(0,i):
            cluster= df[kmeans.labels_ == j]
            #print(cluster["node"])
            print(f"\t{cluster.shape[0]} instances in cluster {j}.")
            print(f"\t\t{IDPsInCluster(cluster)} IDPs and {cluster.shape[0] - IDPsInCluster(cluster)} non IDPs.")
        print("-"*50)
# Out:
# 50 clusters, init : k-means++
# 	131 instances in cluster 0.
# 		1 IDPs and 130 non IDPs.
# 	390 instances in cluster 1.
# 		2 IDPs and 388 non IDPs.
# 	113 instances in cluster 2.
# 		1 IDPs and 112 non IDPs.
# 	55 instances in cluster 3.
# 		4 IDPs and 51 non IDPs.
# 	62 instances in cluster 4.
# 		0 IDPs and 62 non IDPs.
# 	128 instances in cluster 5.
# 		4 IDPs and 124 non IDPs.
# 	40 instances in cluster 6.
# 		3 IDPs and 37 non IDPs.
# 	114 instances in cluster 7.
# 		9 IDPs and 105 non IDPs.
# 	128 instances in cluster 8.
# 		7 IDPs and 121 non IDPs.
# 	188 instances in cluster 9.
# 		6 IDPs and 182 non IDPs.
# 	159 instances in cluster 10.
# 		5 IDPs and 154 non IDPs.
# 	225 instances in cluster 11.
# 		2 IDPs and 223 non IDPs.
# 	117 instances in cluster 12.
# 		8 IDPs and 109 non IDPs.
# 	101 instances in cluster 13.
# 		4 IDPs and 97 non IDPs.
# 	165 instances in cluster 14.
# 		11 IDPs and 154 non IDPs.
# 	45 instances in cluster 15.
# 		0 IDPs and 45 non IDPs.
# 	87 instances in cluster 16.
# 		6 IDPs and 81 non IDPs.
# 	141 instances in cluster 17.
# 		5 IDPs and 136 non IDPs.
# 	4 instances in cluster 18.
# 		0 IDPs and 4 non IDPs.
# 	108 instances in cluster 19.
# 		5 IDPs and 103 non IDPs.
# 	204 instances in cluster 20.
# 		0 IDPs and 204 non IDPs.
# 	47 instances in cluster 21.
# 		2 IDPs and 45 non IDPs.
# 	62 instances in cluster 22.
# 		0 IDPs and 62 non IDPs.
# 	78 instances in cluster 23.
# 		2 IDPs and 76 non IDPs.
# 	77 instances in cluster 24.
# 		14 IDPs and 63 non IDPs.
# 	82 instances in cluster 25.
# 		0 IDPs and 82 non IDPs.
# 	57 instances in cluster 26.
# 		1 IDPs and 56 non IDPs.
# 	73 instances in cluster 27.
# 		7 IDPs and 66 non IDPs.
# 	95 instances in cluster 28.
# 		0 IDPs and 95 non IDPs.
# 	78 instances in cluster 29.
# 		4 IDPs and 74 non IDPs.
# 	18 instances in cluster 30.
# 		1 IDPs and 17 non IDPs.
# 	84 instances in cluster 31.
# 		2 IDPs and 82 non IDPs.
# 	109 instances in cluster 32.
# 		3 IDPs and 106 non IDPs.
# 	116 instances in cluster 33.
# 		10 IDPs and 106 non IDPs.
# 	121 instances in cluster 34.
# 		10 IDPs and 111 non IDPs.
# 	187 instances in cluster 35.
# 		2 IDPs and 185 non IDPs.
# 	37 instances in cluster 36.
# 		1 IDPs and 36 non IDPs.
# 	100 instances in cluster 37.
# 		4 IDPs and 96 non IDPs.
# 	64 instances in cluster 38.
# 		6 IDPs and 58 non IDPs.
# 	39 instances in cluster 39.
# 		0 IDPs and 39 non IDPs.
# 	269 instances in cluster 40.
# 		5 IDPs and 264 non IDPs.
# 	82 instances in cluster 41.
# 		3 IDPs and 79 non IDPs.
# 	109 instances in cluster 42.
# 		4 IDPs and 105 non IDPs.
# 	69 instances in cluster 43.
# 		3 IDPs and 66 non IDPs.
# 	16 instances in cluster 44.
# 		0 IDPs and 16 non IDPs.
# 	102 instances in cluster 45.
# 		5 IDPs and 97 non IDPs.
# 	343 instances in cluster 46.
# 		9 IDPs and 334 non IDPs.
# 	177 instances in cluster 47.
# 		3 IDPs and 174 non IDPs.
# 	32 instances in cluster 48.
# 		0 IDPs and 32 non IDPs.
# 	142 instances in cluster 49.
# 		10 IDPs and 132 non IDPs.
# --------------------------------------------------
# 50 clusters, init : random
# 	146 instances in cluster 0.
# 		9 IDPs and 137 non IDPs.
# 	95 instances in cluster 1.
# 		3 IDPs and 92 non IDPs.
# 	247 instances in cluster 2.
# 		1 IDPs and 246 non IDPs.
# 	234 instances in cluster 3.
# 		5 IDPs and 229 non IDPs.
# 	57 instances in cluster 4.
# 		6 IDPs and 51 non IDPs.
# 	264 instances in cluster 5.
# 		7 IDPs and 257 non IDPs.
# 	279 instances in cluster 6.
# 		4 IDPs and 275 non IDPs.
# 	457 instances in cluster 7.
# 		4 IDPs and 453 non IDPs.
# 	96 instances in cluster 8.
# 		0 IDPs and 96 non IDPs.
# 	16 instances in cluster 9.
# 		0 IDPs and 16 non IDPs.
# 	79 instances in cluster 10.
# 		4 IDPs and 75 non IDPs.
# 	71 instances in cluster 11.
# 		0 IDPs and 71 non IDPs.
# 	31 instances in cluster 12.
# 		3 IDPs and 28 non IDPs.
# 	75 instances in cluster 13.
# 		14 IDPs and 61 non IDPs.
# 	276 instances in cluster 14.
# 		6 IDPs and 270 non IDPs.
# 	69 instances in cluster 15.
# 		1 IDPs and 68 non IDPs.
# 	162 instances in cluster 16.
# 		4 IDPs and 158 non IDPs.
# 	85 instances in cluster 17.
# 		9 IDPs and 76 non IDPs.
# 	75 instances in cluster 18.
# 		5 IDPs and 70 non IDPs.
# 	66 instances in cluster 19.
# 		1 IDPs and 65 non IDPs.
# 	40 instances in cluster 20.
# 		2 IDPs and 38 non IDPs.
# 	44 instances in cluster 21.
# 		1 IDPs and 43 non IDPs.
# 	90 instances in cluster 22.
# 		2 IDPs and 88 non IDPs.
# 	47 instances in cluster 23.
# 		5 IDPs and 42 non IDPs.
# 	168 instances in cluster 24.
# 		1 IDPs and 167 non IDPs.
# 	113 instances in cluster 25.
# 		0 IDPs and 113 non IDPs.
# 	85 instances in cluster 26.
# 		4 IDPs and 81 non IDPs.
# 	111 instances in cluster 27.
# 		4 IDPs and 107 non IDPs.
# 	133 instances in cluster 28.
# 		4 IDPs and 129 non IDPs.
# 	130 instances in cluster 29.
# 		14 IDPs and 116 non IDPs.
# 	227 instances in cluster 30.
# 		0 IDPs and 227 non IDPs.
# 	30 instances in cluster 31.
# 		1 IDPs and 29 non IDPs.
# 	17 instances in cluster 32.
# 		4 IDPs and 13 non IDPs.
# 	51 instances in cluster 33.
# 		0 IDPs and 51 non IDPs.
# 	94 instances in cluster 34.
# 		4 IDPs and 90 non IDPs.
# 	41 instances in cluster 35.
# 		4 IDPs and 37 non IDPs.
# 	101 instances in cluster 36.
# 		4 IDPs and 97 non IDPs.
# 	64 instances in cluster 37.
# 		5 IDPs and 59 non IDPs.
# 	13 instances in cluster 38.
# 		0 IDPs and 13 non IDPs.
# 	73 instances in cluster 39.
# 		4 IDPs and 69 non IDPs.
# 	109 instances in cluster 40.
# 		5 IDPs and 104 non IDPs.
# 	115 instances in cluster 41.
# 		9 IDPs and 106 non IDPs.
# 	60 instances in cluster 42.
# 		1 IDPs and 59 non IDPs.
# 	152 instances in cluster 43.
# 		5 IDPs and 147 non IDPs.
# 	36 instances in cluster 44.
# 		0 IDPs and 36 non IDPs.
# 	107 instances in cluster 45.
# 		9 IDPs and 98 non IDPs.
# 	110 instances in cluster 46.
# 		2 IDPs and 108 non IDPs.
# 	101 instances in cluster 47.
# 		3 IDPs and 98 non IDPs.
# 	41 instances in cluster 48.
# 		1 IDPs and 40 non IDPs.
# 	187 instances in cluster 49.
# 		10 IDPs and 177 non IDPs.
# --------------------------------------------------
# 80 clusters, init : k-means++
# 	141 instances in cluster 0.
# 		4 IDPs and 137 non IDPs.
# 	101 instances in cluster 1.
# 		1 IDPs and 100 non IDPs.
# 	179 instances in cluster 2.
# 		2 IDPs and 177 non IDPs.
# 	140 instances in cluster 3.
# 		13 IDPs and 127 non IDPs.
# 	120 instances in cluster 4.
# 		2 IDPs and 118 non IDPs.
# 	45 instances in cluster 5.
# 		0 IDPs and 45 non IDPs.
# 	93 instances in cluster 6.
# 		5 IDPs and 88 non IDPs.
# 	98 instances in cluster 7.
# 		0 IDPs and 98 non IDPs.
# 	42 instances in cluster 8.
# 		1 IDPs and 41 non IDPs.
# 	35 instances in cluster 9.
# 		2 IDPs and 33 non IDPs.
# 	41 instances in cluster 10.
# 		3 IDPs and 38 non IDPs.
# 	48 instances in cluster 11.
# 		4 IDPs and 44 non IDPs.
# 	55 instances in cluster 12.
# 		0 IDPs and 55 non IDPs.
# 	25 instances in cluster 13.
# 		0 IDPs and 25 non IDPs.
# 	120 instances in cluster 14.
# 		5 IDPs and 115 non IDPs.
# 	65 instances in cluster 15.
# 		1 IDPs and 64 non IDPs.
# 	114 instances in cluster 16.
# 		0 IDPs and 114 non IDPs.
# 	98 instances in cluster 17.
# 		1 IDPs and 97 non IDPs.
# 	67 instances in cluster 18.
# 		2 IDPs and 65 non IDPs.
# 	131 instances in cluster 19.
# 		4 IDPs and 127 non IDPs.
# 	25 instances in cluster 20.
# 		1 IDPs and 24 non IDPs.
# 	78 instances in cluster 21.
# 		10 IDPs and 68 non IDPs.
# 	61 instances in cluster 22.
# 		13 IDPs and 48 non IDPs.
# 	57 instances in cluster 23.
# 		0 IDPs and 57 non IDPs.
# 	105 instances in cluster 24.
# 		5 IDPs and 100 non IDPs.
# 	26 instances in cluster 25.
# 		5 IDPs and 21 non IDPs.
# 	82 instances in cluster 26.
# 		6 IDPs and 76 non IDPs.
# 	10 instances in cluster 27.
# 		0 IDPs and 10 non IDPs.
# 	49 instances in cluster 28.
# 		3 IDPs and 46 non IDPs.
# 	76 instances in cluster 29.
# 		2 IDPs and 74 non IDPs.
# 	2 instances in cluster 30.
# 		0 IDPs and 2 non IDPs.
# 	45 instances in cluster 31.
# 		3 IDPs and 42 non IDPs.
# 	44 instances in cluster 32.
# 		0 IDPs and 44 non IDPs.
# 	62 instances in cluster 33.
# 		0 IDPs and 62 non IDPs.
# 	85 instances in cluster 34.
# 		3 IDPs and 82 non IDPs.
# 	25 instances in cluster 35.
# 		0 IDPs and 25 non IDPs.
# 	92 instances in cluster 36.
# 		1 IDPs and 91 non IDPs.
# 	247 instances in cluster 37.
# 		6 IDPs and 241 non IDPs.
# 	14 instances in cluster 38.
# 		0 IDPs and 14 non IDPs.
# 	37 instances in cluster 39.
# 		0 IDPs and 37 non IDPs.
# 	72 instances in cluster 40.
# 		2 IDPs and 70 non IDPs.
# 	102 instances in cluster 41.
# 		3 IDPs and 99 non IDPs.
# 	96 instances in cluster 42.
# 		3 IDPs and 93 non IDPs.
# 	45 instances in cluster 43.
# 		1 IDPs and 44 non IDPs.
# 	10 instances in cluster 44.
# 		0 IDPs and 10 non IDPs.
# 	64 instances in cluster 45.
# 		2 IDPs and 62 non IDPs.
# 	23 instances in cluster 46.
# 		1 IDPs and 22 non IDPs.
# 	38 instances in cluster 47.
# 		3 IDPs and 35 non IDPs.
# 	19 instances in cluster 48.
# 		1 IDPs and 18 non IDPs.
# 	85 instances in cluster 49.
# 		1 IDPs and 84 non IDPs.
# 	36 instances in cluster 50.
# 		0 IDPs and 36 non IDPs.
# 	21 instances in cluster 51.
# 		5 IDPs and 16 non IDPs.
# 	62 instances in cluster 52.
# 		0 IDPs and 62 non IDPs.
# 	45 instances in cluster 53.
# 		1 IDPs and 44 non IDPs.
# 	121 instances in cluster 54.
# 		4 IDPs and 117 non IDPs.
# 	36 instances in cluster 55.
# 		2 IDPs and 34 non IDPs.
# 	11 instances in cluster 56.
# 		1 IDPs and 10 non IDPs.
# 	56 instances in cluster 57.
# 		6 IDPs and 50 non IDPs.
# 	29 instances in cluster 58.
# 		3 IDPs and 26 non IDPs.
# 	25 instances in cluster 59.
# 		3 IDPs and 22 non IDPs.
# 	166 instances in cluster 60.
# 		2 IDPs and 164 non IDPs.
# 	37 instances in cluster 61.
# 		6 IDPs and 31 non IDPs.
# 	42 instances in cluster 62.
# 		2 IDPs and 40 non IDPs.
# 	21 instances in cluster 63.
# 		0 IDPs and 21 non IDPs.
# 	32 instances in cluster 64.
# 		1 IDPs and 31 non IDPs.
# 	315 instances in cluster 65.
# 		2 IDPs and 313 non IDPs.
# 	14 instances in cluster 66.
# 		1 IDPs and 13 non IDPs.
# 	147 instances in cluster 67.
# 		0 IDPs and 147 non IDPs.
# 	19 instances in cluster 68.
# 		0 IDPs and 19 non IDPs.
# 	193 instances in cluster 69.
# 		8 IDPs and 185 non IDPs.
# 	70 instances in cluster 70.
# 		0 IDPs and 70 non IDPs.
# 	88 instances in cluster 71.
# 		4 IDPs and 84 non IDPs.
# 	68 instances in cluster 72.
# 		2 IDPs and 66 non IDPs.
# 	78 instances in cluster 73.
# 		8 IDPs and 70 non IDPs.
# 	7 instances in cluster 74.
# 		0 IDPs and 7 non IDPs.
# 	94 instances in cluster 75.
# 		2 IDPs and 92 non IDPs.
# 	57 instances in cluster 76.
# 		3 IDPs and 54 non IDPs.
# 	43 instances in cluster 77.
# 		2 IDPs and 41 non IDPs.
# 	52 instances in cluster 78.
# 		1 IDPs and 51 non IDPs.
# 	51 instances in cluster 79.
# 		0 IDPs and 51 non IDPs.
# --------------------------------------------------
# 80 clusters, init : random
# 	82 instances in cluster 0.
# 		3 IDPs and 79 non IDPs.
# 	38 instances in cluster 1.
# 		0 IDPs and 38 non IDPs.
# 	78 instances in cluster 2.
# 		0 IDPs and 78 non IDPs.
# 	1 instances in cluster 3.
# 		0 IDPs and 1 non IDPs.
# 	52 instances in cluster 4.
# 		0 IDPs and 52 non IDPs.
# 	18 instances in cluster 5.
# 		4 IDPs and 14 non IDPs.
# 	1 instances in cluster 6.
# 		0 IDPs and 1 non IDPs.
# 	198 instances in cluster 7.
# 		3 IDPs and 195 non IDPs.
# 	4 instances in cluster 8.
# 		0 IDPs and 4 non IDPs.
# 	36 instances in cluster 9.
# 		2 IDPs and 34 non IDPs.
# 	66 instances in cluster 10.
# 		1 IDPs and 65 non IDPs.
# 	39 instances in cluster 11.
# 		4 IDPs and 35 non IDPs.
# 	108 instances in cluster 12.
# 		9 IDPs and 99 non IDPs.
# 	140 instances in cluster 13.
# 		4 IDPs and 136 non IDPs.
# 	95 instances in cluster 14.
# 		7 IDPs and 88 non IDPs.
# 	57 instances in cluster 15.
# 		7 IDPs and 50 non IDPs.
# 	1 instances in cluster 16.
# 		0 IDPs and 1 non IDPs.
# 	27 instances in cluster 17.
# 		2 IDPs and 25 non IDPs.
# 	60 instances in cluster 18.
# 		0 IDPs and 60 non IDPs.
# 	69 instances in cluster 19.
# 		2 IDPs and 67 non IDPs.
# 	74 instances in cluster 20.
# 		0 IDPs and 74 non IDPs.
# 	43 instances in cluster 21.
# 		1 IDPs and 42 non IDPs.
# 	56 instances in cluster 22.
# 		3 IDPs and 53 non IDPs.
# 	53 instances in cluster 23.
# 		0 IDPs and 53 non IDPs.
# 	4 instances in cluster 24.
# 		0 IDPs and 4 non IDPs.
# 	41 instances in cluster 25.
# 		2 IDPs and 39 non IDPs.
# 	14 instances in cluster 26.
# 		0 IDPs and 14 non IDPs.
# 	204 instances in cluster 27.
# 		4 IDPs and 200 non IDPs.
# 	39 instances in cluster 28.
# 		3 IDPs and 36 non IDPs.
# 	100 instances in cluster 29.
# 		8 IDPs and 92 non IDPs.
# 	86 instances in cluster 30.
# 		5 IDPs and 81 non IDPs.
# 	68 instances in cluster 31.
# 		2 IDPs and 66 non IDPs.
# 	60 instances in cluster 32.
# 		3 IDPs and 57 non IDPs.
# 	28 instances in cluster 33.
# 		0 IDPs and 28 non IDPs.
# 	47 instances in cluster 34.
# 		2 IDPs and 45 non IDPs.
# 	32 instances in cluster 35.
# 		2 IDPs and 30 non IDPs.
# 	38 instances in cluster 36.
# 		1 IDPs and 37 non IDPs.
# 	79 instances in cluster 37.
# 		4 IDPs and 75 non IDPs.
# 	57 instances in cluster 38.
# 		2 IDPs and 55 non IDPs.
# 	146 instances in cluster 39.
# 		4 IDPs and 142 non IDPs.
# 	57 instances in cluster 40.
# 		1 IDPs and 56 non IDPs.
# 	7 instances in cluster 41.
# 		0 IDPs and 7 non IDPs.
# 	12 instances in cluster 42.
# 		0 IDPs and 12 non IDPs.
# 	138 instances in cluster 43.
# 		3 IDPs and 135 non IDPs.
# 	18 instances in cluster 44.
# 		1 IDPs and 17 non IDPs.
# 	26 instances in cluster 45.
# 		5 IDPs and 21 non IDPs.
# 	25 instances in cluster 46.
# 		3 IDPs and 22 non IDPs.
# 	35 instances in cluster 47.
# 		3 IDPs and 32 non IDPs.
# 	65 instances in cluster 48.
# 		0 IDPs and 65 non IDPs.
# 	16 instances in cluster 49.
# 		0 IDPs and 16 non IDPs.
# 	276 instances in cluster 50.
# 		2 IDPs and 274 non IDPs.
# 	253 instances in cluster 51.
# 		1 IDPs and 252 non IDPs.
# 	25 instances in cluster 52.
# 		0 IDPs and 25 non IDPs.
# 	104 instances in cluster 53.
# 		2 IDPs and 102 non IDPs.
# 	8 instances in cluster 54.
# 		1 IDPs and 7 non IDPs.
# 	229 instances in cluster 55.
# 		6 IDPs and 223 non IDPs.
# 	39 instances in cluster 56.
# 		3 IDPs and 36 non IDPs.
# 	20 instances in cluster 57.
# 		0 IDPs and 20 non IDPs.
# 	103 instances in cluster 58.
# 		0 IDPs and 103 non IDPs.
# 	17 instances in cluster 59.
# 		4 IDPs and 13 non IDPs.
# 	68 instances in cluster 60.
# 		13 IDPs and 55 non IDPs.
# 	27 instances in cluster 61.
# 		0 IDPs and 27 non IDPs.
# 	96 instances in cluster 62.
# 		0 IDPs and 96 non IDPs.
# 	26 instances in cluster 63.
# 		0 IDPs and 26 non IDPs.
# 	56 instances in cluster 64.
# 		2 IDPs and 54 non IDPs.
# 	58 instances in cluster 65.
# 		7 IDPs and 51 non IDPs.
# 	47 instances in cluster 66.
# 		0 IDPs and 47 non IDPs.
# 	118 instances in cluster 67.
# 		10 IDPs and 108 non IDPs.
# 	1 instances in cluster 68.
# 		0 IDPs and 1 non IDPs.
# 	98 instances in cluster 69.
# 		8 IDPs and 90 non IDPs.
# 	95 instances in cluster 70.
# 		0 IDPs and 95 non IDPs.
# 	173 instances in cluster 71.
# 		4 IDPs and 169 non IDPs.
# 	18 instances in cluster 72.
# 		0 IDPs and 18 non IDPs.
# 	47 instances in cluster 73.
# 		0 IDPs and 47 non IDPs.
# 	102 instances in cluster 74.
# 		8 IDPs and 94 non IDPs.
# 	102 instances in cluster 75.
# 		3 IDPs and 99 non IDPs.
# 	116 instances in cluster 76.
# 		9 IDPs and 107 non IDPs.
# 	201 instances in cluster 77.
# 		0 IDPs and 201 non IDPs.
# 	59 instances in cluster 78.
# 		1 IDPs and 58 non IDPs.
# 	150 instances in cluster 79.
# 		0 IDPs and 150 non IDPs.
# --------------------------------------------------
# 100 clusters, init : k-means++
# 	19 instances in cluster 0.
# 		0 IDPs and 19 non IDPs.
# 	67 instances in cluster 1.
# 		6 IDPs and 61 non IDPs.
# 	165 instances in cluster 2.
# 		2 IDPs and 163 non IDPs.
# 	36 instances in cluster 3.
# 		1 IDPs and 35 non IDPs.
# 	82 instances in cluster 4.
# 		1 IDPs and 81 non IDPs.
# 	93 instances in cluster 5.
# 		2 IDPs and 91 non IDPs.
# 	21 instances in cluster 6.
# 		1 IDPs and 20 non IDPs.
# 	53 instances in cluster 7.
# 		1 IDPs and 52 non IDPs.
# 	41 instances in cluster 8.
# 		3 IDPs and 38 non IDPs.
# 	168 instances in cluster 9.
# 		0 IDPs and 168 non IDPs.
# 	64 instances in cluster 10.
# 		2 IDPs and 62 non IDPs.
# 	2 instances in cluster 11.
# 		1 IDPs and 1 non IDPs.
# 	34 instances in cluster 12.
# 		2 IDPs and 32 non IDPs.
# 	22 instances in cluster 13.
# 		4 IDPs and 18 non IDPs.
# 	50 instances in cluster 14.
# 		3 IDPs and 47 non IDPs.
# 	18 instances in cluster 15.
# 		1 IDPs and 17 non IDPs.
# 	79 instances in cluster 16.
# 		1 IDPs and 78 non IDPs.
# 	40 instances in cluster 17.
# 		5 IDPs and 35 non IDPs.
# 	43 instances in cluster 18.
# 		11 IDPs and 32 non IDPs.
# 	55 instances in cluster 19.
# 		1 IDPs and 54 non IDPs.
# 	35 instances in cluster 20.
# 		1 IDPs and 34 non IDPs.
# 	44 instances in cluster 21.
# 		2 IDPs and 42 non IDPs.
# 	256 instances in cluster 22.
# 		3 IDPs and 253 non IDPs.
# 	24 instances in cluster 23.
# 		0 IDPs and 24 non IDPs.
# 	60 instances in cluster 24.
# 		0 IDPs and 60 non IDPs.
# 	50 instances in cluster 25.
# 		1 IDPs and 49 non IDPs.
# 	2 instances in cluster 26.
# 		0 IDPs and 2 non IDPs.
# 	65 instances in cluster 27.
# 		1 IDPs and 64 non IDPs.
# 	30 instances in cluster 28.
# 		2 IDPs and 28 non IDPs.
# 	49 instances in cluster 29.
# 		2 IDPs and 47 non IDPs.
# 	85 instances in cluster 30.
# 		1 IDPs and 84 non IDPs.
# 	26 instances in cluster 31.
# 		0 IDPs and 26 non IDPs.
# 	62 instances in cluster 32.
# 		2 IDPs and 60 non IDPs.
# 	120 instances in cluster 33.
# 		2 IDPs and 118 non IDPs.
# 	90 instances in cluster 34.
# 		4 IDPs and 86 non IDPs.
# 	92 instances in cluster 35.
# 		3 IDPs and 89 non IDPs.
# 	18 instances in cluster 36.
# 		1 IDPs and 17 non IDPs.
# 	114 instances in cluster 37.
# 		2 IDPs and 112 non IDPs.
# 	21 instances in cluster 38.
# 		1 IDPs and 20 non IDPs.
# 	55 instances in cluster 39.
# 		0 IDPs and 55 non IDPs.
# 	33 instances in cluster 40.
# 		6 IDPs and 27 non IDPs.
# 	51 instances in cluster 41.
# 		0 IDPs and 51 non IDPs.
# 	46 instances in cluster 42.
# 		1 IDPs and 45 non IDPs.
# 	11 instances in cluster 43.
# 		0 IDPs and 11 non IDPs.
# 	38 instances in cluster 44.
# 		3 IDPs and 35 non IDPs.
# 	115 instances in cluster 45.
# 		1 IDPs and 114 non IDPs.
# 	174 instances in cluster 46.
# 		3 IDPs and 171 non IDPs.
# 	46 instances in cluster 47.
# 		4 IDPs and 42 non IDPs.
# 	110 instances in cluster 48.
# 		1 IDPs and 109 non IDPs.
# 	84 instances in cluster 49.
# 		0 IDPs and 84 non IDPs.
# 	83 instances in cluster 50.
# 		9 IDPs and 74 non IDPs.
# 	31 instances in cluster 51.
# 		0 IDPs and 31 non IDPs.
# 	55 instances in cluster 52.
# 		3 IDPs and 52 non IDPs.
# 	31 instances in cluster 53.
# 		0 IDPs and 31 non IDPs.
# 	24 instances in cluster 54.
# 		2 IDPs and 22 non IDPs.
# 	83 instances in cluster 55.
# 		0 IDPs and 83 non IDPs.
# 	21 instances in cluster 56.
# 		2 IDPs and 19 non IDPs.
# 	59 instances in cluster 57.
# 		3 IDPs and 56 non IDPs.
# 	92 instances in cluster 58.
# 		2 IDPs and 90 non IDPs.
# 	52 instances in cluster 59.
# 		2 IDPs and 50 non IDPs.
# 	41 instances in cluster 60.
# 		0 IDPs and 41 non IDPs.
# 	54 instances in cluster 61.
# 		2 IDPs and 52 non IDPs.
# 	45 instances in cluster 62.
# 		2 IDPs and 43 non IDPs.
# 	10 instances in cluster 63.
# 		0 IDPs and 10 non IDPs.
# 	35 instances in cluster 64.
# 		2 IDPs and 33 non IDPs.
# 	24 instances in cluster 65.
# 		3 IDPs and 21 non IDPs.
# 	38 instances in cluster 66.
# 		2 IDPs and 36 non IDPs.
# 	34 instances in cluster 67.
# 		1 IDPs and 33 non IDPs.
# 	43 instances in cluster 68.
# 		1 IDPs and 42 non IDPs.
# 	52 instances in cluster 69.
# 		0 IDPs and 52 non IDPs.
# 	105 instances in cluster 70.
# 		2 IDPs and 103 non IDPs.
# 	74 instances in cluster 71.
# 		11 IDPs and 63 non IDPs.
# 	50 instances in cluster 72.
# 		1 IDPs and 49 non IDPs.
# 	13 instances in cluster 73.
# 		1 IDPs and 12 non IDPs.
# 	30 instances in cluster 74.
# 		2 IDPs and 28 non IDPs.
# 	57 instances in cluster 75.
# 		1 IDPs and 56 non IDPs.
# 	68 instances in cluster 76.
# 		2 IDPs and 66 non IDPs.
# 	81 instances in cluster 77.
# 		7 IDPs and 74 non IDPs.
# 	13 instances in cluster 78.
# 		0 IDPs and 13 non IDPs.
# 	22 instances in cluster 79.
# 		1 IDPs and 21 non IDPs.
# 	74 instances in cluster 80.
# 		5 IDPs and 69 non IDPs.
# 	19 instances in cluster 81.
# 		1 IDPs and 18 non IDPs.
# 	119 instances in cluster 82.
# 		0 IDPs and 119 non IDPs.
# 	27 instances in cluster 83.
# 		1 IDPs and 26 non IDPs.
# 	84 instances in cluster 84.
# 		1 IDPs and 83 non IDPs.
# 	31 instances in cluster 85.
# 		0 IDPs and 31 non IDPs.
# 	44 instances in cluster 86.
# 		0 IDPs and 44 non IDPs.
# 	57 instances in cluster 87.
# 		0 IDPs and 57 non IDPs.
# 	18 instances in cluster 88.
# 		4 IDPs and 14 non IDPs.
# 	29 instances in cluster 89.
# 		3 IDPs and 26 non IDPs.
# 	82 instances in cluster 90.
# 		3 IDPs and 79 non IDPs.
# 	12 instances in cluster 91.
# 		0 IDPs and 12 non IDPs.
# 	45 instances in cluster 92.
# 		1 IDPs and 44 non IDPs.
# 	43 instances in cluster 93.
# 		0 IDPs and 43 non IDPs.
# 	23 instances in cluster 94.
# 		0 IDPs and 23 non IDPs.
# 	96 instances in cluster 95.
# 		7 IDPs and 89 non IDPs.
# 	83 instances in cluster 96.
# 		5 IDPs and 78 non IDPs.
# 	34 instances in cluster 97.
# 		2 IDPs and 32 non IDPs.
# 	16 instances in cluster 98.
# 		0 IDPs and 16 non IDPs.
# 	56 instances in cluster 99.
# 		2 IDPs and 54 non IDPs.
# --------------------------------------------------
# 100 clusters, init : random
# 	76 instances in cluster 0.
# 		4 IDPs and 72 non IDPs.
# 	1 instances in cluster 1.
# 		0 IDPs and 1 non IDPs.
# 	6 instances in cluster 2.
# 		0 IDPs and 6 non IDPs.
# 	42 instances in cluster 3.
# 		3 IDPs and 39 non IDPs.
# 	6 instances in cluster 4.
# 		0 IDPs and 6 non IDPs.
# 	24 instances in cluster 5.
# 		3 IDPs and 21 non IDPs.
# 	22 instances in cluster 6.
# 		1 IDPs and 21 non IDPs.
# 	91 instances in cluster 7.
# 		5 IDPs and 86 non IDPs.
# 	67 instances in cluster 8.
# 		2 IDPs and 65 non IDPs.
# 	34 instances in cluster 9.
# 		1 IDPs and 33 non IDPs.
# 	85 instances in cluster 10.
# 		6 IDPs and 79 non IDPs.
# 	18 instances in cluster 11.
# 		0 IDPs and 18 non IDPs.
# 	48 instances in cluster 12.
# 		1 IDPs and 47 non IDPs.
# 	14 instances in cluster 13.
# 		0 IDPs and 14 non IDPs.
# 	6 instances in cluster 14.
# 		0 IDPs and 6 non IDPs.
# 	84 instances in cluster 15.
# 		3 IDPs and 81 non IDPs.
# 	82 instances in cluster 16.
# 		12 IDPs and 70 non IDPs.
# 	43 instances in cluster 17.
# 		0 IDPs and 43 non IDPs.
# 	353 instances in cluster 18.
# 		2 IDPs and 351 non IDPs.
# 	15 instances in cluster 19.
# 		0 IDPs and 15 non IDPs.
# 	70 instances in cluster 20.
# 		4 IDPs and 66 non IDPs.
# 	70 instances in cluster 21.
# 		5 IDPs and 65 non IDPs.
# 	50 instances in cluster 22.
# 		2 IDPs and 48 non IDPs.
# 	64 instances in cluster 23.
# 		1 IDPs and 63 non IDPs.
# 	69 instances in cluster 24.
# 		3 IDPs and 66 non IDPs.
# 	45 instances in cluster 25.
# 		2 IDPs and 43 non IDPs.
# 	56 instances in cluster 26.
# 		4 IDPs and 52 non IDPs.
# 	8 instances in cluster 27.
# 		0 IDPs and 8 non IDPs.
# 	1 instances in cluster 28.
# 		0 IDPs and 1 non IDPs.
# 	46 instances in cluster 29.
# 		3 IDPs and 43 non IDPs.
# 	34 instances in cluster 30.
# 		2 IDPs and 32 non IDPs.
# 	77 instances in cluster 31.
# 		2 IDPs and 75 non IDPs.
# 	113 instances in cluster 32.
# 		3 IDPs and 110 non IDPs.
# 	1 instances in cluster 33.
# 		0 IDPs and 1 non IDPs.
# 	115 instances in cluster 34.
# 		1 IDPs and 114 non IDPs.
# 	56 instances in cluster 35.
# 		6 IDPs and 50 non IDPs.
# 	69 instances in cluster 36.
# 		1 IDPs and 68 non IDPs.
# 	176 instances in cluster 37.
# 		3 IDPs and 173 non IDPs.
# 	64 instances in cluster 38.
# 		3 IDPs and 61 non IDPs.
# 	31 instances in cluster 39.
# 		0 IDPs and 31 non IDPs.
# 	25 instances in cluster 40.
# 		3 IDPs and 22 non IDPs.
# 	39 instances in cluster 41.
# 		2 IDPs and 37 non IDPs.
# 	55 instances in cluster 42.
# 		2 IDPs and 53 non IDPs.
# 	15 instances in cluster 43.
# 		0 IDPs and 15 non IDPs.
# 	52 instances in cluster 44.
# 		1 IDPs and 51 non IDPs.
# 	76 instances in cluster 45.
# 		2 IDPs and 74 non IDPs.
# 	29 instances in cluster 46.
# 		5 IDPs and 24 non IDPs.
# 	90 instances in cluster 47.
# 		3 IDPs and 87 non IDPs.
# 	65 instances in cluster 48.
# 		3 IDPs and 62 non IDPs.
# 	28 instances in cluster 49.
# 		3 IDPs and 25 non IDPs.
# 	27 instances in cluster 50.
# 		0 IDPs and 27 non IDPs.
# 	13 instances in cluster 51.
# 		0 IDPs and 13 non IDPs.
# 	40 instances in cluster 52.
# 		1 IDPs and 39 non IDPs.
# 	22 instances in cluster 53.
# 		2 IDPs and 20 non IDPs.
# 	75 instances in cluster 54.
# 		0 IDPs and 75 non IDPs.
# 	37 instances in cluster 55.
# 		3 IDPs and 34 non IDPs.
# 	71 instances in cluster 56.
# 		3 IDPs and 68 non IDPs.
# 	40 instances in cluster 57.
# 		1 IDPs and 39 non IDPs.
# 	38 instances in cluster 58.
# 		2 IDPs and 36 non IDPs.
# 	48 instances in cluster 59.
# 		2 IDPs and 46 non IDPs.
# 	257 instances in cluster 60.
# 		4 IDPs and 253 non IDPs.
# 	43 instances in cluster 61.
# 		0 IDPs and 43 non IDPs.
# 	19 instances in cluster 62.
# 		1 IDPs and 18 non IDPs.
# 	38 instances in cluster 63.
# 		0 IDPs and 38 non IDPs.
# 	37 instances in cluster 64.
# 		2 IDPs and 35 non IDPs.
# 	1 instances in cluster 65.
# 		1 IDPs and 0 non IDPs.
# 	66 instances in cluster 66.
# 		0 IDPs and 66 non IDPs.
# 	59 instances in cluster 67.
# 		1 IDPs and 58 non IDPs.
# 	10 instances in cluster 68.
# 		0 IDPs and 10 non IDPs.
# 	32 instances in cluster 69.
# 		0 IDPs and 32 non IDPs.
# 	14 instances in cluster 70.
# 		1 IDPs and 13 non IDPs.
# 	63 instances in cluster 71.
# 		13 IDPs and 50 non IDPs.
# 	46 instances in cluster 72.
# 		5 IDPs and 41 non IDPs.
# 	48 instances in cluster 73.
# 		3 IDPs and 45 non IDPs.
# 	10 instances in cluster 74.
# 		0 IDPs and 10 non IDPs.
# 	25 instances in cluster 75.
# 		4 IDPs and 21 non IDPs.
# 	34 instances in cluster 76.
# 		0 IDPs and 34 non IDPs.
# 	195 instances in cluster 77.
# 		4 IDPs and 191 non IDPs.
# 	155 instances in cluster 78.
# 		0 IDPs and 155 non IDPs.
# 	13 instances in cluster 79.
# 		0 IDPs and 13 non IDPs.
# 	55 instances in cluster 80.
# 		3 IDPs and 52 non IDPs.
# 	35 instances in cluster 81.
# 		0 IDPs and 35 non IDPs.
# 	66 instances in cluster 82.
# 		3 IDPs and 63 non IDPs.
# 	95 instances in cluster 83.
# 		0 IDPs and 95 non IDPs.
# 	53 instances in cluster 84.
# 		1 IDPs and 52 non IDPs.
# 	36 instances in cluster 85.
# 		1 IDPs and 35 non IDPs.
# 	20 instances in cluster 86.
# 		1 IDPs and 19 non IDPs.
# 	45 instances in cluster 87.
# 		4 IDPs and 41 non IDPs.
# 	87 instances in cluster 88.
# 		7 IDPs and 80 non IDPs.
# 	20 instances in cluster 89.
# 		0 IDPs and 20 non IDPs.
# 	183 instances in cluster 90.
# 		1 IDPs and 182 non IDPs.
# 	86 instances in cluster 91.
# 		3 IDPs and 83 non IDPs.
# 	36 instances in cluster 92.
# 		1 IDPs and 35 non IDPs.
# 	3 instances in cluster 93.
# 		0 IDPs and 3 non IDPs.
# 	96 instances in cluster 94.
# 		0 IDPs and 96 non IDPs.
# 	74 instances in cluster 95.
# 		1 IDPs and 73 non IDPs.
# 	31 instances in cluster 96.
# 		1 IDPs and 30 non IDPs.
# 	76 instances in cluster 97.
# 		0 IDPs and 76 non IDPs.
# 	88 instances in cluster 98.
# 		2 IDPs and 86 non IDPs.
# 	3 instances in cluster 99.
# 		0 IDPs and 3 non IDPs.
# --------------------------------------------------

# %%
def add_cell(figure, subplot_size, plot_ind, x, y, title, y_label):
    fig.add_subplot(subplot_size[0], subplot_size[1], plot_ind)
    plt.plot(x, y, marker = 'o')
    plt.xticks(x)
    plt.title(title)
    plt.xlabel("Broj klastera")
    plt.ylabel(y_label)

# %%
fig = plt.figure(figsize=(10,10))

add_cell(fig, (2, 2), 1, numOfclusters, SSERandom, "SSE Random", "SEE")
add_cell(fig, (2, 2), 2, numOfclusters, SSEKmeans, "SSE k-means++", "SEE")
add_cell(fig, (2, 2), 3, numOfclusters, silhouette_scoresRandom, "Silhouette scores Random", "Silhouette score")
add_cell(fig, (2, 2), 4, numOfclusters, silhouette_scoresKmeans, "Silhouette scores k-means++", "Silhouette score")

plt.tight_layout()
plt.show()
