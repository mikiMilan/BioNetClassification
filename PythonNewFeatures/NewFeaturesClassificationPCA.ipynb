# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("../Data/NewFeatures/disorderPromoting.csv", header=None)
df1Columns = [f"disorderPromoting{i}" for i in range(1, df1.shape[1])]
df1Columns.insert(0, "node")
df1.columns = df1Columns
df1
# Out:
#            node  disorderPromoting1  disorderPromoting2  disorderPromoting3  \
# 0       YDR143C            0.897833            0.049536            0.043344
# 1       YER068W            0.856631            0.057348            0.078853
# 2       YMR207C            0.849287            0.071283            0.068228
# 3       YNR016C            0.860982            0.076923            0.053753
# 4       YIL135C            0.850679            0.085973            0.040724
# ...         ...                 ...                 ...                 ...
# 5565    YJR116W            0.770833            0.072917            0.083333
# 5566    YGR042W            0.846154            0.100000            0.053846
# 5567    YHR002W            0.871951            0.060976            0.054878
# 5568    YBR255W            0.882883            0.042042            0.054054
# 5569  YOR142W-B            0.838951            0.074906            0.069913
#
#       disorderPromoting4  disorderPromoting5  disorderPromoting6  \
# 0               0.000000            0.009288            0.897833
# 1               0.000000            0.007168            0.856631
# 2               0.006110            0.005092            0.849287
# 3               0.002780            0.005561            0.860982
# 4               0.013575            0.009050            0.850679
# ...                  ...                 ...                 ...
# 5565            0.010417            0.062500            0.770833
# 5566            0.000000            0.000000            0.846154
# 5567            0.000000            0.012195            0.871951
# 5568            0.006006            0.015015            0.882883
# 5569            0.006242            0.009988            0.838951
#
#       disorderPromoting7  disorderPromoting8  disorderPromoting9  \
# 0               0.049536            0.043344            0.000000
# 1               0.057348            0.078853            0.000000
# 2               0.071283            0.068228            0.006110
# 3               0.076923            0.053753            0.002780
# 4               0.085973            0.040724            0.013575
# ...                  ...                 ...                 ...
# 5565            0.072917            0.083333            0.010417
# 5566            0.100000            0.053846            0.000000
# 5567            0.060976            0.054878            0.000000
# 5568            0.042042            0.054054            0.006006
# 5569            0.074906            0.069913            0.006242
#
#       disorderPromoting10
# 0                0.009288
# 1                0.007168
# 2                0.005092
# 3                0.005561
# 4                0.009050
# ...                   ...
# 5565             0.062500
# 5566             0.000000
# 5567             0.012195
# 5568             0.015015
# 5569             0.009988
#
# [5570 rows x 11 columns]

# %%
df2 = pd.read_csv("../Data/NewFeatures/hc.csv", header=None)
df2Columns = [f"hc{i}" for i in range(1, df2.shape[1])]
df2Columns.insert(0, "node")
df2.columns = df2Columns
df2
# Out:
#            node       hc1       hc2       hc3       hc4       hc5       hc6  \
# 0       YDR143C  0.363636  0.000000  0.121212  0.060606  0.454545  0.363636
# 1       YER068W  0.293103  0.103448  0.206897  0.034483  0.362069  0.293103
# 2       YMR207C  0.288288  0.063063  0.238739  0.067568  0.342342  0.288288
# 3       YNR016C  0.322870  0.058296  0.215247  0.049327  0.354260  0.322870
# 4       YIL135C  0.323529  0.088235  0.176471  0.088235  0.323529  0.323529
# ...         ...       ...       ...       ...       ...       ...       ...
# 5565    YJR116W  0.416667  0.145833  0.166667  0.062500  0.208333  0.416667
# 5566    YGR042W  0.227273  0.181818  0.227273  0.045455  0.318182  0.227273
# 5567    YHR002W  0.526316  0.052632  0.122807  0.070175  0.228070  0.526316
# 5568    YBR255W  0.448276  0.086207  0.155172  0.068966  0.241379  0.448276
# 5569  YOR142W-B  0.376963  0.078534  0.162304  0.047120  0.335079  0.376963
#
#            hc7       hc8       hc9      hc10
# 0     0.000000  0.121212  0.060606  0.454545
# 1     0.103448  0.206897  0.034483  0.362069
# 2     0.063063  0.238739  0.067568  0.342342
# 3     0.058296  0.215247  0.049327  0.354260
# 4     0.088235  0.176471  0.088235  0.323529
# ...        ...       ...       ...       ...
# 5565  0.145833  0.166667  0.062500  0.208333
# 5566  0.181818  0.227273  0.045455  0.318182
# 5567  0.052632  0.122807  0.070175  0.228070
# 5568  0.086207  0.155172  0.068966  0.241379
# 5569  0.078534  0.162304  0.047120  0.335079
#
# [5570 rows x 11 columns]

# %%
df2ColumnsWONode = df2Columns[1:]
for col in df2ColumnsWONode:
    df2[col].fillna(df2[col].mean(), inplace= True)
    
df2.isna().sum()
# Out:
# node    0
# hc1     0
# hc2     0
# hc3     0
# hc4     0
# hc5     0
# hc6     0
# hc7     0
# hc8     0
# hc9     0
# hc10    0
# dtype: int64

# %%
df3 = pd.read_csv("../Data/NewFeatures/hidrofobik.csv", header=None)
df3Columns = [f"hidrofobik{i}" for i in range(1, df3.shape[1])]
df3Columns.insert(0, "node")
df3.columns = df3Columns
df3
# Out:
#            node  hidrofobik1  hidrofobik2  hidrofobik3  hidrofobik4  \
# 0       YDR143C     0.647887     0.091549     0.133803     0.028169
# 1       YER068W     0.642857     0.119048     0.148810     0.029762
# 2       YMR207C     0.742228     0.084197     0.143782     0.010363
# 3       YNR016C     0.760870     0.077295     0.131643     0.013285
# 4       YIL135C     0.542857     0.095238     0.200000     0.028571
# ...         ...          ...          ...          ...          ...
# 5565    YJR116W     0.880597     0.074627     0.037313     0.000000
# 5566    YGR042W     0.662791     0.104651     0.174419     0.023256
# 5567    YHR002W     0.769784     0.115108     0.079137     0.014388
# 5568    YBR255W     0.675532     0.079787     0.132979     0.026596
# 5569  YOR142W-B     0.650672     0.115163     0.159309     0.023033
#
#       hidrofobik5  hidrofobik6  hidrofobik7  hidrofobik8  hidrofobik9  \
# 0        0.098592     0.647887     0.091549     0.133803     0.028169
# 1        0.059524     0.642857     0.119048     0.148810     0.029762
# 2        0.019430     0.742228     0.084197     0.143782     0.010363
# 3        0.016908     0.760870     0.077295     0.131643     0.013285
# 4        0.133333     0.542857     0.095238     0.200000     0.028571
# ...           ...          ...          ...          ...          ...
# 5565     0.007463     0.880597     0.074627     0.037313     0.000000
# 5566     0.034884     0.662791     0.104651     0.174419     0.023256
# 5567     0.021583     0.769784     0.115108     0.079137     0.014388
# 5568     0.085106     0.675532     0.079787     0.132979     0.026596
# 5569     0.051823     0.650672     0.115163     0.159309     0.023033
#
#       hidrofobik10
# 0         0.098592
# 1         0.059524
# 2         0.019430
# 3         0.016908
# 4         0.133333
# ...            ...
# 5565      0.007463
# 5566      0.034884
# 5567      0.021583
# 5568      0.085106
# 5569      0.051823
#
# [5570 rows x 11 columns]

# %%
df4 = pd.read_csv("../Data/NewFeatures/nonZero.csv", header=None)
df4Columns = [f"nonZero{i}" for i in range(1, df4.shape[1])]
df4Columns.insert(0, "node")
df4.columns = df4Columns
df4
# Out:
#            node  nonZero1  nonZero2  nonZero3  nonZero4  nonZero5  nonZero6  \
# 0       YDR143C  0.983740  0.012195  0.004065       0.0       0.0  0.983740
# 1       YER068W  0.993548  0.006452  0.000000       0.0       0.0  0.993548
# 2       YMR207C  0.983871  0.012903  0.003226       0.0       0.0  0.983871
# 3       YNR016C  0.979087  0.015843  0.005070       0.0       0.0  0.979087
# 4       YIL135C  0.991329  0.008671  0.000000       0.0       0.0  0.991329
# ...         ...       ...       ...       ...       ...       ...       ...
# 5565    YJR116W  0.940476  0.035714  0.023810       0.0       0.0  0.940476
# 5566    YGR042W  0.976077  0.019139  0.004785       0.0       0.0  0.976077
# 5567    YHR002W  0.972222  0.027778  0.000000       0.0       0.0  0.972222
# 5568    YBR255W  0.989170  0.005415  0.005415       0.0       0.0  0.989170
# 5569  YOR142W-B  0.989833  0.009441  0.000726       0.0       0.0  0.989833
#
#       nonZero7  nonZero8  nonZero9  nonZero10
# 0     0.012195  0.004065       0.0        0.0
# 1     0.006452  0.000000       0.0        0.0
# 2     0.012903  0.003226       0.0        0.0
# 3     0.015843  0.005070       0.0        0.0
# 4     0.008671  0.000000       0.0        0.0
# ...        ...       ...       ...        ...
# 5565  0.035714  0.023810       0.0        0.0
# 5566  0.019139  0.004785       0.0        0.0
# 5567  0.027778  0.000000       0.0        0.0
# 5568  0.005415  0.005415       0.0        0.0
# 5569  0.009441  0.000726       0.0        0.0
#
# [5570 rows x 11 columns]

# %%
df5 = pd.read_csv("../Data/NewFeatures/polar.csv", header=None)
df5Columns = [f"polar{i}" for i in range(1, df5.shape[1])]
df5Columns.insert(0, "node")
df5.columns = df5Columns
df5
# Out:
#            node    polar1    polar2    polar3    polar4    polar5    polar6  \
# 0       YDR143C  0.936340  0.034483  0.029178  0.000000  0.000000  0.819742
# 1       YER068W  0.936232  0.026087  0.028986  0.005797  0.002899  0.814050
# 2       YMR207C  0.895401  0.063120  0.034265  0.002705  0.004509  0.861933
# 3       YNR016C  0.885537  0.060337  0.045253  0.005324  0.003549  0.886980
# 4       YIL135C  0.954225  0.031690  0.014085  0.000000  0.000000  0.736842
# ...         ...       ...       ...       ...       ...       ...       ...
# 5565    YJR116W  0.760684  0.128205  0.111111  0.000000  0.000000  0.944444
# 5566    YGR042W  0.944785  0.036810  0.018405  0.000000  0.000000  0.805556
# 5567    YHR002W  0.872832  0.075145  0.046243  0.005780  0.000000  0.891304
# 5568    YBR255W  0.946759  0.027778  0.023148  0.000000  0.002315  0.763359
# 5569  YOR142W-B  0.927536  0.041546  0.029952  0.000966  0.000000  0.800000
#
#         polar7    polar8    polar9   polar10
# 0     0.042918  0.090129  0.012876  0.034335
# 1     0.070248  0.078512  0.012397  0.024793
# 2     0.071006  0.063116  0.001972  0.001972
# 3     0.053345  0.053345  0.005425  0.000904
# 4     0.098684  0.098684  0.006579  0.059211
# ...        ...       ...       ...       ...
# 5565  0.024691  0.024691  0.000000  0.006173
# 5566  0.074074  0.101852  0.000000  0.018519
# 5567  0.048913  0.043478  0.005435  0.010870
# 5568  0.083969  0.099237  0.022901  0.030534
# 5569  0.079167  0.093056  0.012500  0.015278
#
# [5570 rows x 11 columns]

# %%
df6 = pd.read_csv("../Data/NewFeatures/positive.csv", header=None)
df6Columns = [f"positive{i}" for i in range(1, df6.shape[1])]
df6Columns.insert(0, "node")
df6.columns = df6Columns
df6
# Out:
#            node  positive1  positive2  positive3  positive4  positive5  \
# 0       YDR143C   0.912676   0.039437   0.033803   0.008451   0.005634
# 1       YER068W   0.910448   0.050746   0.032836   0.000000   0.005970
# 2       YMR207C   0.923957   0.044154   0.030253   0.001635   0.000000
# 3       YNR016C   0.940377   0.030943   0.027925   0.000755   0.000000
# 4       YIL135C   0.914634   0.036585   0.040650   0.004065   0.004065
# ...         ...        ...        ...        ...        ...        ...
# 5565    YJR116W   0.974093   0.015544   0.010363   0.000000   0.000000
# 5566    YGR042W   0.915493   0.028169   0.056338   0.000000   0.000000
# 5567    YHR002W   0.942222   0.031111   0.026667   0.000000   0.000000
# 5568    YBR255W   0.905759   0.044503   0.044503   0.002618   0.002618
# 5569  YOR142W-B   0.921844   0.047094   0.029058   0.000000   0.002004
#
#       positive6  positive7  positive8  positive9  positive10
# 0      0.912676   0.039437   0.033803   0.008451    0.005634
# 1      0.910448   0.050746   0.032836   0.000000    0.005970
# 2      0.923957   0.044154   0.030253   0.001635    0.000000
# 3      0.940377   0.030943   0.027925   0.000755    0.000000
# 4      0.914634   0.036585   0.040650   0.004065    0.004065
# ...         ...        ...        ...        ...         ...
# 5565   0.974093   0.015544   0.010363   0.000000    0.000000
# 5566   0.915493   0.028169   0.056338   0.000000    0.000000
# 5567   0.942222   0.031111   0.026667   0.000000    0.000000
# 5568   0.905759   0.044503   0.044503   0.002618    0.002618
# 5569   0.921844   0.047094   0.029058   0.000000    0.002004
#
# [5570 rows x 11 columns]

# %%
merged_df = pd.merge(df1, df2, on='node')
merged_df = pd.merge(merged_df, df3, on='node')
merged_df = pd.merge(merged_df, df4, on='node')
merged_df = pd.merge(merged_df, df5, on='node')
merged_df = pd.merge(merged_df, df6, on='node')
merged_df
# Out:
#            node  disorderPromoting1  disorderPromoting2  disorderPromoting3  \
# 0       YDR143C            0.897833            0.049536            0.043344
# 1       YER068W            0.856631            0.057348            0.078853
# 2       YMR207C            0.849287            0.071283            0.068228
# 3       YNR016C            0.860982            0.076923            0.053753
# 4       YIL135C            0.850679            0.085973            0.040724
# ...         ...                 ...                 ...                 ...
# 5565    YJR116W            0.770833            0.072917            0.083333
# 5566    YGR042W            0.846154            0.100000            0.053846
# 5567    YHR002W            0.871951            0.060976            0.054878
# 5568    YBR255W            0.882883            0.042042            0.054054
# 5569  YOR142W-B            0.838951            0.074906            0.069913
#
#       disorderPromoting4  disorderPromoting5  disorderPromoting6  \
# 0               0.000000            0.009288            0.897833
# 1               0.000000            0.007168            0.856631
# 2               0.006110            0.005092            0.849287
# 3               0.002780            0.005561            0.860982
# 4               0.013575            0.009050            0.850679
# ...                  ...                 ...                 ...
# 5565            0.010417            0.062500            0.770833
# 5566            0.000000            0.000000            0.846154
# 5567            0.000000            0.012195            0.871951
# 5568            0.006006            0.015015            0.882883
# 5569            0.006242            0.009988            0.838951
#
#       disorderPromoting7  disorderPromoting8  disorderPromoting9  ...  \
# 0               0.049536            0.043344            0.000000  ...
# 1               0.057348            0.078853            0.000000  ...
# 2               0.071283            0.068228            0.006110  ...
# 3               0.076923            0.053753            0.002780  ...
# 4               0.085973            0.040724            0.013575  ...
# ...                  ...                 ...                 ...  ...
# 5565            0.072917            0.083333            0.010417  ...
# 5566            0.100000            0.053846            0.000000  ...
# 5567            0.060976            0.054878            0.000000  ...
# 5568            0.042042            0.054054            0.006006  ...
# 5569            0.074906            0.069913            0.006242  ...
#
#       positive1  positive2  positive3  positive4  positive5  positive6  \
# 0      0.912676   0.039437   0.033803   0.008451   0.005634   0.912676
# 1      0.910448   0.050746   0.032836   0.000000   0.005970   0.910448
# 2      0.923957   0.044154   0.030253   0.001635   0.000000   0.923957
# 3      0.940377   0.030943   0.027925   0.000755   0.000000   0.940377
# 4      0.914634   0.036585   0.040650   0.004065   0.004065   0.914634
# ...         ...        ...        ...        ...        ...        ...
# 5565   0.974093   0.015544   0.010363   0.000000   0.000000   0.974093
# 5566   0.915493   0.028169   0.056338   0.000000   0.000000   0.915493
# 5567   0.942222   0.031111   0.026667   0.000000   0.000000   0.942222
# 5568   0.905759   0.044503   0.044503   0.002618   0.002618   0.905759
# 5569   0.921844   0.047094   0.029058   0.000000   0.002004   0.921844
#
#       positive7  positive8  positive9  positive10
# 0      0.039437   0.033803   0.008451    0.005634
# 1      0.050746   0.032836   0.000000    0.005970
# 2      0.044154   0.030253   0.001635    0.000000
# 3      0.030943   0.027925   0.000755    0.000000
# 4      0.036585   0.040650   0.004065    0.004065
# ...         ...        ...        ...         ...
# 5565   0.015544   0.010363   0.000000    0.000000
# 5566   0.028169   0.056338   0.000000    0.000000
# 5567   0.031111   0.026667   0.000000    0.000000
# 5568   0.044503   0.044503   0.002618    0.002618
# 5569   0.047094   0.029058   0.000000    0.002004
#
# [5570 rows x 61 columns]

# %%
#dataFrame = dataFrame[dataFrame.columns[0:15]]
#dataFrame

# %%
#L = [(dataFrame.columns[0])]
#L +=  list(dataFrame.columns[15:29])
#dataFrame = dataFrame[L]
#dataFrame

# %%
with open ("../Data/yeast/disprotYeast194.txt", "r") as inputFile:
    disProt = [line.strip() for line in inputFile]

# %%
def assignLabel(node, IDPs):
    if node in IDPs:
        return 1
    return 0

# %%
labels = []
for node in merged_df["node"]:
    labels.append(assignLabel(node, disProt))
    
merged_df.insert(1, "label", labels)
merged_df
# Out:
#            node  label  disorderPromoting1  disorderPromoting2  \
# 0       YDR143C      1            0.897833            0.049536
# 1       YER068W      0            0.856631            0.057348
# 2       YMR207C      0            0.849287            0.071283
# 3       YNR016C      1            0.860982            0.076923
# 4       YIL135C      0            0.850679            0.085973
# ...         ...    ...                 ...                 ...
# 5565    YJR116W      0            0.770833            0.072917
# 5566    YGR042W      0            0.846154            0.100000
# 5567    YHR002W      0            0.871951            0.060976
# 5568    YBR255W      0            0.882883            0.042042
# 5569  YOR142W-B      0            0.838951            0.074906
#
#       disorderPromoting3  disorderPromoting4  disorderPromoting5  \
# 0               0.043344            0.000000            0.009288
# 1               0.078853            0.000000            0.007168
# 2               0.068228            0.006110            0.005092
# 3               0.053753            0.002780            0.005561
# 4               0.040724            0.013575            0.009050
# ...                  ...                 ...                 ...
# 5565            0.083333            0.010417            0.062500
# 5566            0.053846            0.000000            0.000000
# 5567            0.054878            0.000000            0.012195
# 5568            0.054054            0.006006            0.015015
# 5569            0.069913            0.006242            0.009988
#
#       disorderPromoting6  disorderPromoting7  disorderPromoting8  ...  \
# 0               0.897833            0.049536            0.043344  ...
# 1               0.856631            0.057348            0.078853  ...
# 2               0.849287            0.071283            0.068228  ...
# 3               0.860982            0.076923            0.053753  ...
# 4               0.850679            0.085973            0.040724  ...
# ...                  ...                 ...                 ...  ...
# 5565            0.770833            0.072917            0.083333  ...
# 5566            0.846154            0.100000            0.053846  ...
# 5567            0.871951            0.060976            0.054878  ...
# 5568            0.882883            0.042042            0.054054  ...
# 5569            0.838951            0.074906            0.069913  ...
#
#       positive1  positive2  positive3  positive4  positive5  positive6  \
# 0      0.912676   0.039437   0.033803   0.008451   0.005634   0.912676
# 1      0.910448   0.050746   0.032836   0.000000   0.005970   0.910448
# 2      0.923957   0.044154   0.030253   0.001635   0.000000   0.923957
# 3      0.940377   0.030943   0.027925   0.000755   0.000000   0.940377
# 4      0.914634   0.036585   0.040650   0.004065   0.004065   0.914634
# ...         ...        ...        ...        ...        ...        ...
# 5565   0.974093   0.015544   0.010363   0.000000   0.000000   0.974093
# 5566   0.915493   0.028169   0.056338   0.000000   0.000000   0.915493
# 5567   0.942222   0.031111   0.026667   0.000000   0.000000   0.942222
# 5568   0.905759   0.044503   0.044503   0.002618   0.002618   0.905759
# 5569   0.921844   0.047094   0.029058   0.000000   0.002004   0.921844
#
#       positive7  positive8  positive9  positive10
# 0      0.039437   0.033803   0.008451    0.005634
# 1      0.050746   0.032836   0.000000    0.005970
# 2      0.044154   0.030253   0.001635    0.000000
# 3      0.030943   0.027925   0.000755    0.000000
# 4      0.036585   0.040650   0.004065    0.004065
# ...         ...        ...        ...         ...
# 5565   0.015544   0.010363   0.000000    0.000000
# 5566   0.028169   0.056338   0.000000    0.000000
# 5567   0.031111   0.026667   0.000000    0.000000
# 5568   0.044503   0.044503   0.002618    0.002618
# 5569   0.047094   0.029058   0.000000    0.002004
#
# [5570 rows x 62 columns]

# %%
embeding = pd.read_csv("../Data/NewEmbedings/embed_p2_q1_notW.csv", header=None)
embeding
# Out:
#             0         1         2         3         4         5         6    \
# 0       YDR143C  0.489355 -0.133820 -0.104743  0.355404  0.248795  0.082276
# 1       YER068W -0.181563 -0.106796 -0.251416  0.133842  0.290794  0.046451
# 2       YMR207C -0.127260 -0.376882  0.007594  0.197129  0.034433 -0.177042
# 3       YNR016C  0.120612 -0.389956  0.042595  0.266715  0.239850 -0.317591
# 4       YIL135C -0.137359 -0.522142 -0.188407  0.095474 -0.002379 -0.012450
# ...         ...       ...       ...       ...       ...       ...       ...
# 5635    YGR042W  0.037341 -0.163460  0.061125 -0.004426  0.008056 -0.047935
# 5636    YHR002W  0.193310 -0.347681 -0.157674  0.083066  0.028100 -0.197454
# 5637    YBR255W  0.107947 -0.224621 -0.229771  0.146322  0.159148 -0.235389
# 5638   TS(AGA)A  0.073116 -0.243561 -0.175079  0.282072  0.202851 -0.227292
# 5639  YOR142W-B  0.096220 -0.195939 -0.023665  0.133309  0.262208 -0.194695
#
#            7         8         9    ...       119       120       121  \
# 0    -0.393408  0.462355  0.424525  ... -0.342792 -0.037661 -0.010074
# 1    -0.372687  0.223309  0.281151  ... -0.177044 -0.517876  0.014820
# 2    -0.017106  0.111959  0.035569  ...  0.078918 -0.064612 -0.116809
# 3     0.062092 -0.064162 -0.082341  ... -0.043434 -0.160771 -0.255714
# 4     0.000927  0.152697  0.139736  ...  0.375822 -0.203216 -0.283696
# ...        ...       ...       ...  ...       ...       ...       ...
# 5635 -0.080931  0.206594  0.209294  ...  0.017505 -0.069286 -0.113899
# 5636  0.029697  0.367927  0.151034  ...  0.155770  0.175897 -0.036742
# 5637 -0.207438  0.191829  0.067555  ...  0.240121 -0.044798 -0.366436
# 5638 -0.515775  0.076924  0.166144  ...  0.132517  0.085604 -0.174474
# 5639 -0.120185  0.219112  0.394333  ...  0.098908  0.016317 -0.123577
#
#            122       123       124       125       126       127       128
# 0    -0.011061 -0.127494 -0.124377  0.156678  0.227350 -0.379476 -0.437927
# 1     0.090105 -0.351522 -0.533959 -0.272060  0.015745 -0.596109 -0.217360
# 2    -0.012231 -0.282247 -0.113117  0.156484 -0.064082 -0.096498 -0.031781
# 3     0.011584 -0.132607 -0.388262 -0.016025  0.149189  0.060363  0.231024
# 4     0.048688 -0.136596  0.231517  0.119675  0.202780 -0.023230 -0.067822
# ...        ...       ...       ...       ...       ...       ...       ...
# 5635 -0.074234 -0.098797  0.162219 -0.005060  0.061725 -0.016395 -0.073249
# 5636  0.275517 -0.038799 -0.064079 -0.195498 -0.030828  0.251061 -0.044431
# 5637  0.228716 -0.174457  0.023809 -0.071392  0.065229 -0.221041  0.026377
# 5638  0.401801 -0.050438  0.244951  0.065264  0.389543 -0.132763 -0.124885
# 5639  0.238211 -0.276999  0.096169 -0.099909  0.018608 -0.022034  0.067858
#
# [5640 rows x 129 columns]

# %%
columnsEmbeding = [f"embeding{i}" for i in range(1, embeding.shape[1])]
columnsEmbeding.insert(0, "node")
embeding.columns = columnsEmbeding
embeding
# Out:
#            node  embeding1  embeding2  embeding3  embeding4  embeding5  \
# 0       YDR143C   0.489355  -0.133820  -0.104743   0.355404   0.248795
# 1       YER068W  -0.181563  -0.106796  -0.251416   0.133842   0.290794
# 2       YMR207C  -0.127260  -0.376882   0.007594   0.197129   0.034433
# 3       YNR016C   0.120612  -0.389956   0.042595   0.266715   0.239850
# 4       YIL135C  -0.137359  -0.522142  -0.188407   0.095474  -0.002379
# ...         ...        ...        ...        ...        ...        ...
# 5635    YGR042W   0.037341  -0.163460   0.061125  -0.004426   0.008056
# 5636    YHR002W   0.193310  -0.347681  -0.157674   0.083066   0.028100
# 5637    YBR255W   0.107947  -0.224621  -0.229771   0.146322   0.159148
# 5638   TS(AGA)A   0.073116  -0.243561  -0.175079   0.282072   0.202851
# 5639  YOR142W-B   0.096220  -0.195939  -0.023665   0.133309   0.262208
#
#       embeding6  embeding7  embeding8  embeding9  ...  embeding119  \
# 0      0.082276  -0.393408   0.462355   0.424525  ...    -0.342792
# 1      0.046451  -0.372687   0.223309   0.281151  ...    -0.177044
# 2     -0.177042  -0.017106   0.111959   0.035569  ...     0.078918
# 3     -0.317591   0.062092  -0.064162  -0.082341  ...    -0.043434
# 4     -0.012450   0.000927   0.152697   0.139736  ...     0.375822
# ...         ...        ...        ...        ...  ...          ...
# 5635  -0.047935  -0.080931   0.206594   0.209294  ...     0.017505
# 5636  -0.197454   0.029697   0.367927   0.151034  ...     0.155770
# 5637  -0.235389  -0.207438   0.191829   0.067555  ...     0.240121
# 5638  -0.227292  -0.515775   0.076924   0.166144  ...     0.132517
# 5639  -0.194695  -0.120185   0.219112   0.394333  ...     0.098908
#
#       embeding120  embeding121  embeding122  embeding123  embeding124  \
# 0       -0.037661    -0.010074    -0.011061    -0.127494    -0.124377
# 1       -0.517876     0.014820     0.090105    -0.351522    -0.533959
# 2       -0.064612    -0.116809    -0.012231    -0.282247    -0.113117
# 3       -0.160771    -0.255714     0.011584    -0.132607    -0.388262
# 4       -0.203216    -0.283696     0.048688    -0.136596     0.231517
# ...           ...          ...          ...          ...          ...
# 5635    -0.069286    -0.113899    -0.074234    -0.098797     0.162219
# 5636     0.175897    -0.036742     0.275517    -0.038799    -0.064079
# 5637    -0.044798    -0.366436     0.228716    -0.174457     0.023809
# 5638     0.085604    -0.174474     0.401801    -0.050438     0.244951
# 5639     0.016317    -0.123577     0.238211    -0.276999     0.096169
#
#       embeding125  embeding126  embeding127  embeding128
# 0        0.156678     0.227350    -0.379476    -0.437927
# 1       -0.272060     0.015745    -0.596109    -0.217360
# 2        0.156484    -0.064082    -0.096498    -0.031781
# 3       -0.016025     0.149189     0.060363     0.231024
# 4        0.119675     0.202780    -0.023230    -0.067822
# ...           ...          ...          ...          ...
# 5635    -0.005060     0.061725    -0.016395    -0.073249
# 5636    -0.195498    -0.030828     0.251061    -0.044431
# 5637    -0.071392     0.065229    -0.221041     0.026377
# 5638     0.065264     0.389543    -0.132763    -0.124885
# 5639    -0.099909     0.018608    -0.022034     0.067858
#
# [5640 rows x 129 columns]

# %%
merged_df = pd.merge(merged_df, embeding, on='node')
merged_df
# Out:
#            node  label  disorderPromoting1  disorderPromoting2  \
# 0       YDR143C      1            0.897833            0.049536
# 1       YER068W      0            0.856631            0.057348
# 2       YMR207C      0            0.849287            0.071283
# 3       YNR016C      1            0.860982            0.076923
# 4       YIL135C      0            0.850679            0.085973
# ...         ...    ...                 ...                 ...
# 5565    YJR116W      0            0.770833            0.072917
# 5566    YGR042W      0            0.846154            0.100000
# 5567    YHR002W      0            0.871951            0.060976
# 5568    YBR255W      0            0.882883            0.042042
# 5569  YOR142W-B      0            0.838951            0.074906
#
#       disorderPromoting3  disorderPromoting4  disorderPromoting5  \
# 0               0.043344            0.000000            0.009288
# 1               0.078853            0.000000            0.007168
# 2               0.068228            0.006110            0.005092
# 3               0.053753            0.002780            0.005561
# 4               0.040724            0.013575            0.009050
# ...                  ...                 ...                 ...
# 5565            0.083333            0.010417            0.062500
# 5566            0.053846            0.000000            0.000000
# 5567            0.054878            0.000000            0.012195
# 5568            0.054054            0.006006            0.015015
# 5569            0.069913            0.006242            0.009988
#
#       disorderPromoting6  disorderPromoting7  disorderPromoting8  ...  \
# 0               0.897833            0.049536            0.043344  ...
# 1               0.856631            0.057348            0.078853  ...
# 2               0.849287            0.071283            0.068228  ...
# 3               0.860982            0.076923            0.053753  ...
# 4               0.850679            0.085973            0.040724  ...
# ...                  ...                 ...                 ...  ...
# 5565            0.770833            0.072917            0.083333  ...
# 5566            0.846154            0.100000            0.053846  ...
# 5567            0.871951            0.060976            0.054878  ...
# 5568            0.882883            0.042042            0.054054  ...
# 5569            0.838951            0.074906            0.069913  ...
#
#       embeding119  embeding120  embeding121  embeding122  embeding123  \
# 0       -0.342792    -0.037661    -0.010074    -0.011061    -0.127494
# 1       -0.177044    -0.517876     0.014820     0.090105    -0.351522
# 2        0.078918    -0.064612    -0.116809    -0.012231    -0.282247
# 3       -0.043434    -0.160771    -0.255714     0.011584    -0.132607
# 4        0.375822    -0.203216    -0.283696     0.048688    -0.136596
# ...           ...          ...          ...          ...          ...
# 5565     0.124380     0.043094    -0.157688    -0.137584    -0.139322
# 5566     0.017505    -0.069286    -0.113899    -0.074234    -0.098797
# 5567     0.155770     0.175897    -0.036742     0.275517    -0.038799
# 5568     0.240121    -0.044798    -0.366436     0.228716    -0.174457
# 5569     0.098908     0.016317    -0.123577     0.238211    -0.276999
#
#       embeding124  embeding125  embeding126  embeding127  embeding128
# 0       -0.124377     0.156678     0.227350    -0.379476    -0.437927
# 1       -0.533959    -0.272060     0.015745    -0.596109    -0.217360
# 2       -0.113117     0.156484    -0.064082    -0.096498    -0.031781
# 3       -0.388262    -0.016025     0.149189     0.060363     0.231024
# 4        0.231517     0.119675     0.202780    -0.023230    -0.067822
# ...           ...          ...          ...          ...          ...
# 5565     0.119691    -0.026695     0.044442     0.046044    -0.134722
# 5566     0.162219    -0.005060     0.061725    -0.016395    -0.073249
# 5567    -0.064079    -0.195498    -0.030828     0.251061    -0.044431
# 5568     0.023809    -0.071392     0.065229    -0.221041     0.026377
# 5569     0.096169    -0.099909     0.018608    -0.022034     0.067858
#
# [5570 rows x 190 columns]

# %%
for col in merged_df.columns:
    print(col)
# Out:
# node
# label
# disorderPromoting1
# disorderPromoting2
# disorderPromoting3
# disorderPromoting4
# disorderPromoting5
# disorderPromoting6
# disorderPromoting7
# disorderPromoting8
# disorderPromoting9
# disorderPromoting10
# hc1
# hc2
# hc3
# hc4
# hc5
# hc6
# hc7
# hc8
# hc9
# hc10
# hidrofobik1
# hidrofobik2
# hidrofobik3
# hidrofobik4
# hidrofobik5
# hidrofobik6
# hidrofobik7
# hidrofobik8
# hidrofobik9
# hidrofobik10
# nonZero1
# nonZero2
# nonZero3
# nonZero4
# nonZero5
# nonZero6
# nonZero7
# nonZero8
# nonZero9
# nonZero10
# polar1
# polar2
# polar3
# polar4
# polar5
# polar6
# polar7
# polar8
# polar9
# polar10
# positive1
# positive2
# positive3
# positive4
# positive5
# positive6
# positive7
# positive8
# positive9
# positive10
# embeding1
# embeding2
# embeding3
# embeding4
# embeding5
# embeding6
# embeding7
# embeding8
# embeding9
# embeding10
# embeding11
# embeding12
# embeding13
# embeding14
# embeding15
# embeding16
# embeding17
# embeding18
# embeding19
# embeding20
# embeding21
# embeding22
# embeding23
# embeding24
# embeding25
# embeding26
# embeding27
# embeding28
# embeding29
# embeding30
# embeding31
# embeding32
# embeding33
# embeding34
# embeding35
# embeding36
# embeding37
# embeding38
# embeding39
# embeding40
# embeding41
# embeding42
# embeding43
# embeding44
# embeding45
# embeding46
# embeding47
# embeding48
# embeding49
# embeding50
# embeding51
# embeding52
# embeding53
# embeding54
# embeding55
# embeding56
# embeding57
# embeding58
# embeding59
# embeding60
# embeding61
# embeding62
# embeding63
# embeding64
# embeding65
# embeding66
# embeding67
# embeding68
# embeding69
# embeding70
# embeding71
# embeding72
# embeding73
# embeding74
# embeding75
# embeding76
# embeding77
# embeding78
# embeding79
# embeding80
# embeding81
# embeding82
# embeding83
# embeding84
# embeding85
# embeding86
# embeding87
# embeding88
# embeding89
# embeding90
# embeding91
# embeding92
# embeding93
# embeding94
# embeding95
# embeding96
# embeding97
# embeding98
# embeding99
# embeding100
# embeding101
# embeding102
# embeding103
# embeding104
# embeding105
# embeding106
# embeding107
# embeding108
# embeding109
# embeding110
# embeding111
# embeding112
# embeding113
# embeding114
# embeding115
# embeding116
# embeding117
# embeding118
# embeding119
# embeding120
# embeding121
# embeding122
# embeding123
# embeding124
# embeding125
# embeding126
# embeding127
# embeding128

# %%
x = merged_df[merged_df.columns[2::]]
x
# Out:
#       disorderPromoting1  disorderPromoting2  disorderPromoting3  \
# 0               0.897833            0.049536            0.043344
# 1               0.856631            0.057348            0.078853
# 2               0.849287            0.071283            0.068228
# 3               0.860982            0.076923            0.053753
# 4               0.850679            0.085973            0.040724
# ...                  ...                 ...                 ...
# 5565            0.770833            0.072917            0.083333
# 5566            0.846154            0.100000            0.053846
# 5567            0.871951            0.060976            0.054878
# 5568            0.882883            0.042042            0.054054
# 5569            0.838951            0.074906            0.069913
#
#       disorderPromoting4  disorderPromoting5  disorderPromoting6  \
# 0               0.000000            0.009288            0.897833
# 1               0.000000            0.007168            0.856631
# 2               0.006110            0.005092            0.849287
# 3               0.002780            0.005561            0.860982
# 4               0.013575            0.009050            0.850679
# ...                  ...                 ...                 ...
# 5565            0.010417            0.062500            0.770833
# 5566            0.000000            0.000000            0.846154
# 5567            0.000000            0.012195            0.871951
# 5568            0.006006            0.015015            0.882883
# 5569            0.006242            0.009988            0.838951
#
#       disorderPromoting7  disorderPromoting8  disorderPromoting9  \
# 0               0.049536            0.043344            0.000000
# 1               0.057348            0.078853            0.000000
# 2               0.071283            0.068228            0.006110
# 3               0.076923            0.053753            0.002780
# 4               0.085973            0.040724            0.013575
# ...                  ...                 ...                 ...
# 5565            0.072917            0.083333            0.010417
# 5566            0.100000            0.053846            0.000000
# 5567            0.060976            0.054878            0.000000
# 5568            0.042042            0.054054            0.006006
# 5569            0.074906            0.069913            0.006242
#
#       disorderPromoting10  ...  embeding119  embeding120  embeding121  \
# 0                0.009288  ...    -0.342792    -0.037661    -0.010074
# 1                0.007168  ...    -0.177044    -0.517876     0.014820
# 2                0.005092  ...     0.078918    -0.064612    -0.116809
# 3                0.005561  ...    -0.043434    -0.160771    -0.255714
# 4                0.009050  ...     0.375822    -0.203216    -0.283696
# ...                   ...  ...          ...          ...          ...
# 5565             0.062500  ...     0.124380     0.043094    -0.157688
# 5566             0.000000  ...     0.017505    -0.069286    -0.113899
# 5567             0.012195  ...     0.155770     0.175897    -0.036742
# 5568             0.015015  ...     0.240121    -0.044798    -0.366436
# 5569             0.009988  ...     0.098908     0.016317    -0.123577
#
#       embeding122  embeding123  embeding124  embeding125  embeding126  \
# 0       -0.011061    -0.127494    -0.124377     0.156678     0.227350
# 1        0.090105    -0.351522    -0.533959    -0.272060     0.015745
# 2       -0.012231    -0.282247    -0.113117     0.156484    -0.064082
# 3        0.011584    -0.132607    -0.388262    -0.016025     0.149189
# 4        0.048688    -0.136596     0.231517     0.119675     0.202780
# ...           ...          ...          ...          ...          ...
# 5565    -0.137584    -0.139322     0.119691    -0.026695     0.044442
# 5566    -0.074234    -0.098797     0.162219    -0.005060     0.061725
# 5567     0.275517    -0.038799    -0.064079    -0.195498    -0.030828
# 5568     0.228716    -0.174457     0.023809    -0.071392     0.065229
# 5569     0.238211    -0.276999     0.096169    -0.099909     0.018608
#
#       embeding127  embeding128
# 0       -0.379476    -0.437927
# 1       -0.596109    -0.217360
# 2       -0.096498    -0.031781
# 3        0.060363     0.231024
# 4       -0.023230    -0.067822
# ...           ...          ...
# 5565     0.046044    -0.134722
# 5566    -0.016395    -0.073249
# 5567     0.251061    -0.044431
# 5568    -0.221041     0.026377
# 5569    -0.022034     0.067858
#
# [5570 rows x 188 columns]

# %%
y = merged_df["label"]
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 5565    0
# 5566    0
# 5567    0
# 5568    0
# 5569    0
# Name: label, Length: 5570, dtype: int64

# %%
import imblearn as im
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced
from collections import Counter
from sklearn.decomposition import PCA
import numpy as np

def report_imbalanced(model, x, y, text = "training"):
    y_pred = model.predict(x)
    
    print("Classification report for model {} on {} data".format(type(model).__name__, text))
    print("---------------------------------------------------------------------------------")
    print(classification_report_imbalanced(y, y_pred, zero_division=True))
    print("---------------------------------------------------------------------------------")
    
    print("Confusion matrix for model {} on {} data ".format(type(model).__name__, text))
    print("---------------------------------------------------------------------------------")
    print(pd.DataFrame(confusion_matrix(y, y_pred), columns=['0', '1'], index=['0', '1']))
    print("---------------------------------------------------------------------------------")

def resample(sampler, x, y):
    x_resampled, y_resampled = sampler.fit_resample(x, y)
    print("Number of instances before resampling with {} : {}. ".format(type(sampler).__name__,\
                                                                           Counter(y).items()))
    print("Number of instances after  resampling with {} : {}. ".format(type(sampler).__name__,\
                                                                           Counter(y_resampled).items()))
    return x_resampled, y_resampled

def visualize(x, x_resampled, y, y_resampled, x_opacity=0.5):
    
    pca = PCA(n_components=2)
    pca.fit(x)
    
    x_pca = pca.transform(x)
    x_resampled_pca = pca.transform(x_resampled) 
    
    x_stacked = [x_pca, x_resampled_pca]
    y_stacked = [y, y_resampled]
    
    fig = plt.figure(figsize=(20, 5))
    
    for i in range(2):
        ax = plt.subplot(1, 2, i + 1)
        colors = ['b' if y == 0 else 'r' for y in y_stacked[i]]
        alpha = [x_opacity if y == -1 else 1 - x_opacity for y in y_stacked[i]]
        plt.scatter(x_stacked[i][:, 0], x_stacked[i][:, 1], c=colors, alpha=alpha)
        plt.title('{} resampling'.format("After" if i else "Before"), c = 'blue' if i else 'green')
    plt.show()
    
def train_and_evaluate_model(model, x_train, y_train, x_test, y_test):
    model.fit(x_train, y_train)
    report_imbalanced(model, x_train, y_train, "training")
    report_imbalanced(model, x_test, y_test, "test")
    return model

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, stratify=y)

# %%
'''
from sklearn.preprocessing import MinMaxScaler, StandardScaler
scaler = MinMaxScaler()
scaler.fit(x_train)
x_train = pd.DataFrame(scaler.transform(x_train), columns=x_train.columns)
x_test = pd.DataFrame(scaler.transform(x_test), columns=x_test.columns)
''';

# %%
'''
from imblearn.over_sampling import SMOTE
smote = SMOTE(sampling_strategy= 0.2)
x_resampled, y_resampled = resample(smote, x_train, y_train)
visualize(x_train, x_resampled, y_train, y_resampled, 0)
''';

# %%
#x_resampled = x_train
#y_resampled = y_train

# %%
from imblearn.combine import SMOTEENN
smoteenn = SMOTEENN(sampling_strategy= 0.4)
x_resampled, y_resampled = resample(smoteenn, x_train, y_train)
visualize(x_train, x_resampled, y_train, y_resampled, 0.5)
# Out:
# Number of instances before resampling with SMOTEENN : dict_items([(0, 3763), (1, 136)]).
# Number of instances after  resampling with SMOTEENN : dict_items([(0, 2982), (1, 1502)]).

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
scaler = StandardScaler()
scaler.fit(x_resampled)
x_resampled = pd.DataFrame(scaler.transform(x_resampled), columns=x_resampled.columns)
x_test = pd.DataFrame(scaler.transform(x_test), columns=x_test.columns)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=0.99)
pca.fit(x_resampled)
# Out:
# PCA(n_components=0.99)

# %%
columnsPCA = [f"pca_{i}" for i in range(1, pca.n_components_ + 1)]
len(columnsPCA)
# Out:
# 144

# %%
x_train_pca = pd.DataFrame(pca.transform(x_resampled), columns=columnsPCA)
x_test_pca = pd.DataFrame(pca.transform(x_test), columns=columnsPCA)

# %%
#scaler = MinMaxScaler()
#scaler.fit(x_train_pca)
#x_train_pca = pd.DataFrame(scaler.transform(x_train_pca), columns=columnsPCA)
#x_test_pca = pd.DataFrame(scaler.transform(x_test_pca), columns=columnsPCA)

# %%
#from sklearn.model_selection import GridSearchCV

#params = {'n_neighbors': range(5, 20, 2),
          #'weights': ['uniform', 'distance'],
          #'p': [1, 2]
        # }

# %%
#import xgboost as xgb

#model = xgb.XGBClassifier()
#model.fit(x_resampled, y_resampled)

# %%
#from sklearn.ensemble import RandomForestClassifier

#model = RandomForestClassifier(n_estimators=100)
#model.fit(x_resampled, y_resampled)

# %%
#from sklearn.ensemble import AdaBoostClassifier

#model = AdaBoostClassifier(n_estimators=50)
#model.fit(x_resampled, y_resampled)

# %%
#from sklearn.ensemble import GradientBoostingClassifier

#model = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=3)
#model.fit(x_resampled, y_resampled)

# %%
#from sklearn.svm import SVC

#model = SVC()
#model.fit(x_resampled, y_resampled)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import GridSearchCV

params = {'n_neighbors': range(5, 20, 1),
          'weights': ['uniform', 'distance'],
          'p': [1, 2]
         }

estimator = GridSearchCV(KNeighborsClassifier(), param_grid=params, cv=3, scoring= "recall")
estimator.fit(x_train_pca, y_resampled)

model = BaggingClassifier(estimator=estimator.best_estimator_, n_estimators=50)
model.fit(x_train_pca, y_resampled)
# Out:
# BaggingClassifier(estimator=KNeighborsClassifier(p=1), n_estimators=50)

# %%
#from sklearn.svm import SVC
#from sklearn.model_selection import GridSearchCV

#params = [
           # {
                #'kernel': ['linear'],
                #'C': [0.01, 0.1, 1, 10],
            #},
            #{
             #   'kernel': ['rbf', 'poly', 'sigmoid'],
              #  'C': [0.01, 0.1, 1, 10],
              #  'gamma': [0.01, 0.1, 1, 10],
            #},
        # ]

# %%
#estimator = GridSearchCV(SVC(), params, scoring='recall', cv=5, verbose=5)
#estimator.fit(x_resampled, y_resampled)
#model = estimator.best_estimator_

# %%
'''
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

params = {
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'criterion': ['gini', 'entropy']
}

estimator = GridSearchCV(RandomForestClassifier(), param_grid=params, cv=3, scoring='f1')
estimator.fit(x_resampled, y_resampled)
model = estimator.best_estimator_
''';

# %%
#report_imbalanced(model, x_resampled, y_resampled, "Training")

# %%
report_imbalanced(model, x_test_pca, y_test, "Test")
# Out:
# Classification report for model BaggingClassifier on Test data
# ---------------------------------------------------------------------------------
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.98      0.78      0.64      0.87      0.71      0.50      1613
#           1       0.09      0.64      0.78      0.16      0.71      0.49        58
#
# avg / total       0.95      0.77      0.64      0.85      0.71      0.50      1671
#
# ---------------------------------------------------------------------------------
# Confusion matrix for model BaggingClassifier on Test data
# ---------------------------------------------------------------------------------
#       0    1
# 0  1257  356
# 1    21   37
# ---------------------------------------------------------------------------------

# %%
'''
import numpy as np
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# Convert features and labels to NumPy arrays
X_train_np = np.array(X_train)
#y_train_np = np.array(labels)



# Train individual classifiers
clf1 = GradientBoostingClassifier()
clf1.fit(X_train_np[:, :10], y_train)  # Train using first 10features

clf2 = GradientBoostingClassifier()
clf2.fit(X_train_np[:, 10:40], y_train)  # Train using next 10 features



# Combine classifiers into a voting ensemble
voting_clf = VotingClassifier(estimators=[('gb1', clf1), ('gb2', clf2)], voting='hard')

# Train the voting classifier
voting_clf.fit(X_train_np, y_train)

y_pred = voting_clf.predict(X_test)
''';
